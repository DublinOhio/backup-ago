# %% [markdown]
# # Backup HFLs to AGO
#
# Create static snapshots of HFLs for archiving and backup purposes in AGO
#
# ### References:
#
# https://developers.arcgis.com/rest/users-groups-and-items/export-item.htm
#
# [How To: Back up hosted content by looping through and downloading hosted feature services in FGDB format](https://support.esri.com/en/technical-article/000022524)
#
# [How To: Back up content in ArcGIS Online](https://support.esri.com/en/technical-article/000011795)
#
# [How To: Download feature service items from ArcGIS Online using ArcGIS API for Python](https://support.esri.com/en/technical-article/000018909)
#
# Searching content https://developers.arcgis.com/python/guide/accessing-and-creating-content/

# %% [markdown]
# ### Imports

# %%
import os
import uuid
import json
import shutil
import tempfile
from time import strftime
# need to be able to round up
from math import ceil 

##import pandas as pd

from arcgis.gis import GIS
from arcgis import __version__

# %% [markdown]
# #### initialize GIS

# %%
gis = GIS("home")
# Out:
# /opt/conda/lib/python3.9/site-packages/arcgis/gis/__init__.py:703: UserWarning: You are logged on as DublinOhio with an administrator role, proceed with caution.
#   warnings.warn(

# %% [markdown]
# # Delete current contents of backup folder.
#
# ## First, search for all file geodatabases
#
# ## Then, find those that are in the ownerFolder for my GIS backups, delete those.

# %%
backups_folder = "f74cc94ec1dc4ac8b8a16742c799b4fb"

allmyfgdbs = gis.content.search("owner:DublinOhio", max_items = 2000, item_type = "File Geodatabase")

len(allmyfgdbs)
# Out:
# 237

# %%
allmyfgdbs[:10] # first 10
# Out:
# [<Item title:"Agreement Areas Edit" type:File Geodatabase owner:DublinOhio>,
#  <Item title:"2011 Aerial Grid Edit" type:File Geodatabase owner:DublinOhio>,
#  <Item title:"Cache Update Boundary Edit" type:File Geodatabase owner:DublinOhio>,
#  <Item title:"Memorial Tournament POI Edit" type:File Geodatabase owner:DublinOhio>,
#  <Item title:"Other Parks Edit" type:File Geodatabase owner:DublinOhio>,
#  <Item title:"Trash Cans Edit" type:File Geodatabase owner:DublinOhio>,
#  <Item title:"Playgrounds Edit" type:File Geodatabase owner:DublinOhio>,
#  <Item title:"Metro Occupancy Rates Edit" type:File Geodatabase owner:DublinOhio>,
#  <Item title:"School Districts Edit" type:File Geodatabase owner:DublinOhio>,
#  <Item title:"Service Districts Edit" type:File Geodatabase owner:DublinOhio>]

# %%
items_in_bkflder = []

for item in allmyfgdbs:
    
    # folder id for GIS Layers Backups. 
    # this is finding all the existing backups that are in that specified folder
    if item["ownerFolder"] == backups_folder:
        items_in_bkflder.append(item)
# Out:
# Previous backup deletion completed

# %%
items_in_bkflder
# Out:
# []

# %% [markdown]
# ## Delete previous backups in batches
# Can't delet batches of size 100 or more now; so need to delete content in batches < n=100

# %%
def backup_deleter(list_of_items_to_delete):
    
    print("Starting backup_deleter...")
    n_backups = len(list_of_items_to_delete)

    # when backups are already gone we don't need to delete them.
    if n_backups > 0:

        #get number of batches needed, each batch can be max 100 
        n_batches = ceil(n_backups/100.00)
        print("Chop the list of backups to delete into {} batches".format(n_batches))

        # https://numpy.org/doc/stable/reference/generated/numpy.array_split.html#numpy.array_split
        # split batch list into about equal numbers per batch
        batch_list = np.array_split(list_of_items_to_delete, n_batches)

        for i in batch_list:
            print("Batch length: ",len(i))

        for i, batch in enumerate(batch_list):
            print("starting batch ", i+1)
            
            try:
                gis.content.delete_items(items = batch)
            except Exception as error:
                # handle the exception
                print("An exception occurred:", error) 
                
            print("\tBatch complete")

    else:
        pass
    
    if len(items_in_bkflder) > 0:
        print("\tResult:\t!!!Hey there's still backups in the backup folder that weren't deleted!!!")

    elif len(items_in_bkflder) == 0:
        print("\tResult:\tPrevious backup deletion completed, len(items_in_bkflder) ==0")

# %%
backup_deleter(items_in_bkflder)
# Out:
# Starting backup_deleter...
# 	Result:	Previous backup deletion completed, len(items_in_bkflder) ==0

# %% [markdown]
# Properties of an item, found ownerFolder from here
#
# ```#from pprint import pprint
# #pprint(vars(mycontent[2]))```
#
# ```{'_depend': <Dependencies for ff35d0b42fd841188c5b564909686eb0>,
#  '_gis': GIS @ https://www.arcgis.com version:9.3,
#  '_hydrated': False,
#  '_portal': <arcgis.gis._impl._portalpy.Portal object at 0x7fbe182e8cd0>,
#  '_workdir': '/tmp',
#  'access': 'private',
#  'accessInformation': 'City of Dublin, Ohio, USA',
#  'advancedSettings': None,
#  'appCategories': [],
#  'avgRating': 0,
#  'banner': None,
#  'categories': [],
#  'created': 1633824388000,
#  'culture': 'en-us',
#  'description': 'Trees planted and maintained by the City in the right-of-way '
#                 'of Dublin OH, USA. These trees are typically found between '
#                 'the sidewalk and the street in the &quot;tree lawn&quot;.',
#  'documentation': None,
#  'extent': [[-83.20229096510711, 40.065185068482265],
#             [-83.08937282431096, 40.16284924299875]],
#  'groupDesignations': None,
#  'guid': None,
#  'id': 'ff35d0b42fd841188c5b564909686eb0',
#  'industries': [],
#  'isOrgItem': True,
#  'itemid': 'ff35d0b42fd841188c5b564909686eb0',
#  'languages': [],
#  'largeThumbnail': None,
#  'licenseInfo': None,
#  'listed': False,
#  'modified': 1633824455000,
#  'name': 'Street_Trees_Edit_AsOf_20211010T000014.zip',
#  'numComments': 0,
#  'numRatings': 0,
#  'numViews': 0,
#  'owner': 'DublinOhio',
#  'ownerFolder': 'f74cc94ec1dc4ac8b8a16742c799b4fb',
#  'properties': None,
#  'protected': False,
#  'proxyFilter': None,
#  'scoreCompleteness': 61,
#  'screenshots': [],
#  'snippet': 'Trees planted and maintained in the right-of-way of Dublin OH, '
#             'USA',
#  'spatialReference': '102723',
#  'subInfo': 0,
#  'tags': ['Arboriculture', 'Trees', 'Urban Forestry'],
#  'thumbnail': None,
#  'title': 'Street_Trees_Edit_AsOf_20211010T000014',
#  'type': 'File Geodatabase',
#  'typeKeywords': ['File Geodatabase'],
#  'url': None}```

# %% [markdown]
# # Create list of content to backup
# ## Important! Filter input
# ####  `"tags:HFLBackupIncludeYes"` A specific tag for filter
# #### `item_type="Feature Layer"` , Only get Feature Layer types
#
# otherwise the created GDBs may be included and backup content that does not need to be.

# %%
def makeBkupList(backupTag = "HFLBackupIncludeYes"):
    
    ######
    # INPUT: tag that identifies feature layers for backups
    # OUTPUT: list of Feature layers that have the corresponding tag
    
    ######
    
    
    print("Searching for content with tag: ", backupTag)
    bkupContentList = gis.content.search(query="tags:"+ backupTag, 
                                item_type="Feature *",  #Feature Service, Feature Layer, Feature Collection
                                max_items=2000)
    print("Query Results to Backup:\n", bkupContentList)
    return bkupContentList

# %% [markdown]
# # Function to Create the Backups

# %%
# Source framework, expanded upon.
# "Back up hosted content by looping through and downloading hosted feature services in FGDB format"
# https://support.esri.com/en/technical-article/000022524

def backupItems(bkupList, bkupFolder = "GIS Layers Backups"):
    ######
    # INPUT: List of items to backup, and output destination
    # OUTPUT: returns list of output item IDs and messaging for processes
    
    ######
    timestamp = strftime("%Y%m%dT%H%M%S")
    
    # for naming timestamp in ISO 8601 compliant 
    print("Timestamp is {}\nExporting {} items to destination {}\n\n".format(timestamp, len(bkupList), bkupFolder))
    
    outputItemIDs = []
    outputItmeNames = []
    
    for idx, item in enumerate(bkupList):
        
        try:
    
            dataitem = gis.content.get(item.id)
            print("Processing item: ", item, "ID: ", dataitem)

            
            try:
                print("\tExporting item")
                result = dataitem.export(item.title, "File Geodatabase", parameters = None)
                print("\tExporting item complete")
            except:
                print("Failed Exporting Item")

            try:
                
                print("\tMoving item to", bkupFolder)
                result.move(bkupFolder, owner = "DublinOhio")
                print("\tMoving item complete")
            except:
                print("Failed to move item")
                

            print("\tItem {} of total {} complete".format((idx + 1), len(bkupList)))

            print("\tID of backup", result.id)
            print("\n******\n")
            outputItemIDs.append(result.id)
        
        except:
            print("Failed somewhere")
    
    print("Export to GDBs complete. List of output item IDs available\nID List: ", outputItemIDs)
    
    for item in outputItemIDs:
        i = gis.content.get(item)
        print("\t", i.title, " ID --->\t", i.id)
    return outputItemIDs

# %% [markdown]
# # Function to Clean up content
#
# ## Find the new content we just created
#
# The backup function returns a list of backup item IDs if defined
# i.e. `backups = backupItems(bkupList,  bkupFolder = "GIS Layers Backups")`

# %% [markdown]
# ### Remove tag used to flag for backups
#
# Function to remove clutter tags such as the Backup Notice tag so it will not appear in future searches for this.
#
# i.e. `removeBkupTag(['Test', 'IncludeInBackups', 'HFLBackupIncludeYes'])` returns
# ```
# Original Tags
# 	 ['Test', 'IncludeInBackups', 'HFLBackupIncludeYes']
# 	New Tags
# 	 ['Test', 'IncludeInBackups']
# ```

# %%
def removeBkupTag(TagList, removeTags = ["HFLBackupIncludeYes"]):
    # Defined a default tag HFLBackupIncludeYes but this can be any list of tags.

    
    tagsClean = [n for n in TagList if n not in removeTags]
    
    print("Original Tags\n\t", TagList, "\n\tNew Tags\n\t", tagsClean)
    
    return tagsClean

# %%
def updateTags(itemID):
    # Takes in item ID then updates and removes backup tags
    
    item = gis.content.get(itemID)
    print("Updating tags on item:", item)
    
    # Call the remove backup tag function 
    newTags = removeBkupTag(item.tags)
    
    # Update the tags with the clean list. 
    item.update(item_properties={'tags':newTags})
    
    print("\tConfirmed: tags after update:\n\t", item.tags)

# %%
def removeBackupTagsFromBackups(backupResults):
    for item in backupResults:
        updateTags(item)

# %% [markdown]
# # Run the Backups

# %%
# make a list of items to backup by the tag specified.

bkupList = makeBkupList(backupTag = "HFLBackupIncludeYes")


bkupList
# Out:
# Searching for content with tag:  HFLBackupIncludeYes
# Query Results to Backup:
#  [<Item title:"Zipcodes Edit" type:Feature Layer Collection owner:DublinOhio>, <Item title:"Capital Improvement Projects Edit" type:Feature Layer Collection owner:DublinOhio>, <Item title:"Walls Edit" type:Feature Layer Collection owner:DublinOhio>, <Item title:"Subdivision Sections Edit" type:Feature Layer Collection owner:DublinOhio>, <Item title:"Tree Canopy Detail Edit" type:Feature Layer Collection owner:DublinOhio>, <Item title:"Culverts Edit" type:Feature Layer Collection owner:DublinOhio>, <Item title:"Emergency Detour Routes Edit" type:Feature Layer Collection owner:DublinOhio>, <Item title:"Floodplain Historic 2007 Edit" type:Feature Layer Collection owner:DublinOhio>, <Item title:"EMA Event Area Edit" type:Feature Layer Collection owner:DublinOhio>, <Item title:"Backwater Valve Inventory Edit" type:Feature Layer Collection owner:DublinOhio>, <Item title:"Crashes Edit Copied" type:Feature Layer Collection owner:DublinOhio>, <Item title:"Landscaping Contracts Edit" type:Feature Layer Collection owner:DublinOhio>, <Item title:"CVT Edit" type:Feature Layer Collection owner:DublinOhio>, <Item title:"Edit Mule" type:Feature Layer Collection owner:DublinOhio>, <Item title:"Other Bikeways Edit" type:Feature Layer Collection owner:DublinOhio>, <Item title:"High School Attendance Areas" type:Feature Layer Collection owner:DublinOhio>, <Item title:"Traffic Signal Poles Edit" type:Feature Layer Collection owner:DublinOhio>, <Item title:"Water Utility Edit" type:Feature Layer Collection owner:DublinOhio>, <Item title:"Memorial Tournament Parking Lot and Street No Parking Signage Edit" type:Feature Layer Collection owner:DublinOhio>, <Item title:"DORA Businesses Edit" type:Feature Layer Collection owner:DublinOhio>, <Item title:"Zoning Edit" type:Feature Layer Collection owner:DublinOhio>, <Item title:"Event Signage Edit" type:Feature Layer Collection owner:DublinOhio>, <Item title:"City Facilities Edit" type:Feature Layer Collection owner:DublinOhio>, <Item title:"Ward_Boundary_Work_Neigh_Validate" type:Feature Layer Collection owner:DublinOhio>, <Item title:"EMA Structure Inspection Edit" type:Feature Layer Collection owner:DublinOhio>, <Item title:"Bridge Street District Non-Study Area Edit" type:Feature Layer Collection owner:DublinOhio>, <Item title:"Floodplain Edit" type:Feature Layer Collection owner:DublinOhio>, <Item title:"Bridge Street District Study Area Edit" type:Feature Layer Collection owner:DublinOhio>, <Item title:"EMA Event Point Edit" type:Feature Layer Collection owner:DublinOhio>, <Item title:"Electric Poles Edit" type:Feature Layer Collection owner:DublinOhio>, <Item title:"DIF Grid Edit" type:Feature Layer Collection owner:DublinOhio>, <Item title:"Census Block Groups 2010 Edit" type:Feature Layer Collection owner:DublinOhio>, <Item title:"Scenic Roads Edit" type:Feature Layer Collection owner:DublinOhio>, <Item title:"Deer Auto Collisions Edit" type:Feature Layer Collection owner:DublinOhio>, <Item title:"Cache Update Boundary Edit" type:Feature Layer Collection owner:DublinOhio>, <Item title:"Other Parks Edit" type:Feature Layer Collection owner:DublinOhio>, <Item title:"Number of Lanes Edit" type:Feature Layer Collection owner:DublinOhio>, <Item title:"Cultural Assessment Structures Edit" type:Feature Layer Collection owner:DublinOhio>, <Item title:"Bedrock Edit" type:Feature Layer Collection owner:DublinOhio>, <Item title:"Decks Docks Stairs Edit" type:Feature Layer Collection owner:rjtaylor@dublin.oh.us_DublinOhio>, <Item title:"Commercial Trees Edit" type:Feature Layer Collection owner:DublinOhio>, <Item title:"Restroom Facilities Edit" type:Feature Layer Collection owner:DublinOhio>, <Item title:"Other Agreement Areas Edit" type:Feature Layer Collection owner:DublinOhio>, <Item title:"Historic District Structure Info Edit" type:Feature Layer Collection owner:DublinOhio>, <Item title:"Memorial Tournament POI Edit" type:Feature Layer Collection owner:DublinOhio>, <Item title:"Floodplain FIRM Panels Ed ...
# [<Item title:"Zipcodes Edit" type:Feature Layer Collection owner:DublinOhio>,
#  <Item title:"Capital Improvement Projects Edit" type:Feature Layer Collection owner:DublinOhio>,
#  <Item title:"Walls Edit" type:Feature Layer Collection owner:DublinOhio>,
#  <Item title:"Subdivision Sections Edit" type:Feature Layer Collection owner:DublinOhio>,
#  <Item title:"Tree Canopy Detail Edit" type:Feature Layer Collection owner:DublinOhio>,
#  <Item title:"Culverts Edit" type:Feature Layer Collection owner:DublinOhio>,
#  <Item title:"Emergency Detour Routes Edit" type:Feature Layer Collection owner:DublinOhio>,
#  <Item title:"Floodplain Historic 2007 Edit" type:Feature Layer Collection owner:DublinOhio>,
#  <Item title:"EMA Event Area Edit" type:Feature Layer Collection owner:DublinOhio>,
#  <Item title:"Backwater Valve Inventory Edit" type:Feature Layer Collection owner:DublinOhio>,
#  <Item title:"Crashes Edit Copied" type:Feature Layer Collection owner:DublinOhio>,
#  <Item title:"Landscaping Contracts Edit" type:Feature Layer Collection owner:DublinOhio>,
#  <Item title:"CVT Edit" type:Feature Layer Collection owner:DublinOhio>,
#  <Item title:"Edit Mule" type:Feature Layer Collection owner:DublinOhio>,
#  <Item title:"Other Bikeways Edit" type:Feature Layer Collection owner:DublinOhio>,
#  <Item title:"High School Attendance Areas" type:Feature Layer Collection owner:DublinOhio>,
#  <Item title:"Traffic Signal Poles Edit" type:Feature Layer Collection owner:DublinOhio>,
#  <Item title:"Water Utility Edit" type:Feature Layer Collection owner:DublinOhio>,
#  <Item title:"Memorial Tournament Parking Lot and Street No Parking Signage Edit" type:Feature Layer Collection owner:DublinOhio>,
#  <Item title:"DORA Businesses Edit" type:Feature Layer Collection owner:DublinOhio>,
#  <Item title:"Zoning Edit" type:Feature Layer Collection owner:DublinOhio>,
#  <Item title:"Event Signage Edit" type:Feature Layer Collection owner:DublinOhio>,
#  <Item title:"City Facilities Edit" type:Feature Layer Collection owner:DublinOhio>,
#  <Item title:"Ward_Boundary_Work_Neigh_Validate" type:Feature Layer Collection owner:DublinOhio>,
#  <Item title:"EMA Structure Inspection Edit" type:Feature Layer Collection owner:DublinOhio>,
#  <Item title:"Bridge Street District Non-Study Area Edit" type:Feature Layer Collection owner:DublinOhio>,
#  <Item title:"Floodplain Edit" type:Feature Layer Collection owner:DublinOhio>,
#  <Item title:"Bridge Street District Study Area Edit" type:Feature Layer Collection owner:DublinOhio>,
#  <Item title:"EMA Event Point Edit" type:Feature Layer Collection owner:DublinOhio>,
#  <Item title:"Electric Poles Edit" type:Feature Layer Collection owner:DublinOhio>,
#  <Item title:"DIF Grid Edit" type:Feature Layer Collection owner:DublinOhio>,
#  <Item title:"Census Block Groups 2010 Edit" type:Feature Layer Collection owner:DublinOhio>,
#  <Item title:"Scenic Roads Edit" type:Feature Layer Collection owner:DublinOhio>,
#  <Item title:"Deer Auto Collisions Edit" type:Feature Layer Collection owner:DublinOhio>,
#  <Item title:"Cache Update Boundary Edit" type:Feature Layer Collection owner:DublinOhio>,
#  <Item title:"Other Parks Edit" type:Feature Layer Collection owner:DublinOhio>,
#  <Item title:"Number of Lanes Edit" type:Feature Layer Collection owner:DublinOhio>,
#  <Item title:"Cultural Assessment Structures Edit" type:Feature Layer Collection owner:DublinOhio>,
#  <Item title:"Bedrock Edit" type:Feature Layer Collection owner:DublinOhio>,
#  <Item title:"Decks Docks Stairs Edit" type:Feature Layer Collection owner:rjtaylor@dublin.oh.us_DublinOhio>,
#  <Item title:"Commercial Trees Edit" type:Feature Layer Collection owner:DublinOhio>,
#  <Item title:"Restroom Facilities Edit" type:Feature Layer Collection owner:DublinOhio>,
#  <Item title:"Other Agreement Areas Edit" type:Feature Layer Collection owner:DublinOhio>,
#  <Item title:"Historic District Structure Info Edit" type:Feature Layer Collection owner:DublinOhio>,
#  <Item title:"Memorial Tournament POI Edit" type:Feature Layer Collection owner:DublinOhio>,
#  <Item title:"Floodplain FIRM Panels Edit" type:Feature Layer Collection owner:DublinOhio>,
#  <Item title:"Bridge Rails Edit" type:Feature Layer Collection owner:DublinOhio>,
#  <Item title:"Dublin Database" type:Feature Layer Collection owner:DublinOhio>,
#  <Item title:"Entry Exit Counter" type:Feature Layer Collection owner:DublinOhio>,
#  <Item title:"Acquisition Comments Edit" type:Feature Layer Collection owner:DublinOhio>,
#  <Item title:"Memorial Tournament No Parking Zones Edit" type:Feature Layer Collection owner:DublinOhio>,
#  <Item title:"Snow Zones Edit" type:Feature Layer Collection owner:DublinOhio>,
#  <Item title:"School Districts Edit" type:Feature Layer Collection owner:DublinOhio>,
#  <Item title:"Service Districts Edit" type:Feature Layer Collection owner:DublinOhio>,
#  <Item title:"Intersections Edit" type:Feature Layer Collection owner:DublinOhio>,
#  <Item title:"Signs Edit" type:Feature Layer Collection owner:DublinOhio>,
#  <Item title:"Pavement Striping" type:Feature Layer Collection owner:DublinOhio>,
#  <Item title:"Bikeway Signed Route Edit" type:Feature Layer Collection owner:DublinOhio>,
#  <Item title:"Storm Sewer Edit" type:Feature Layer Collection owner:DublinOhio>,
#  <Item title:"Buildings Edit" type:Feature Layer Collection owner:DublinOhio>,
#  <Item title:"Community Event Race Routes Equipment Edit" type:Feature Layer Collection owner:DublinOhio>,
#  <Item title:"Dublink Regional (Outer Loop and Downtown)" type:Feature Layer Collection owner:DublinOhio>,
#  <Item title:"Storm Mains Fieldwork Edit" type:Feature Layer Collection owner:DublinOhio>,
#  <Item title:"Cellular Towers Edit" type:Feature Layer Collection owner:DublinOhio>,
#  <Item title:"Non-Dublin Area Edit" type:Feature Layer Collection owner:DublinOhio>,
#  <Item title:"Stream Protection Zone Edit" type:Feature Layer Collection owner:DublinOhio>,
#  <Item title:"Independence Day Grid Edit" type:Feature Layer Collection owner:DublinOhio>,
#  <Item title:"Watersheds Edit" type:Feature Layer Collection owner:DublinOhio>,
#  <Item title:"Parcel Update Boundary Edit" type:Feature Layer Collection owner:DublinOhio>,
#  <Item title:"Water Main Breaks Edit" type:Feature Layer Collection owner:DublinOhio>,
#  <Item title:"Cultural Assessment Walls Edit" type:Feature Layer Collection owner:DublinOhio>,
#  <Item title:"Floodplain LOMR Edit" type:Feature Layer Collection owner:DublinOhio>,
#  <Item title:"Medians Edit" type:Feature Layer Collection owner:DublinOhio>,
#  <Item title:"Memorial Tournament Cones Edit" type:Feature Layer Collection owner:DublinOhio>,
#  <Item title:"City Facilities GoDublin Edit" type:Feature Layer Collection owner:DublinOhio>,
#  <Item title:"Future Land Use 2012 Edit (Current Production)" type:Feature Layer Collection owner:DublinOhio>,
#  <Item title:"Architectural Review District Edit" type:Feature Layer Collection owner:DublinOhio>,
#  <Item title:"Dublin Water and Sewer Service Area Edit" type:Feature Layer Collection owner:DublinOhio>,
#  <Item title:"Cellular Infrastructure - Edit" type:Feature Layer Collection owner:DublinOhio>,
#  <Item title:"Non DEM Area Edit" type:Feature Layer Collection owner:DublinOhio>,
#  <Item title:"Forever Dublin Addresses Edit" type:Feature Layer Collection owner:DublinOhio>,
#  <Item title:"Construction Projects Edit" type:Feature Layer Collection owner:DublinOhio>,
#  <Item title:"Irrigation Lines Edit" type:Feature Layer Collection owner:DublinOhio>,
#  <Item title:"Indian Mounds Edit" type:Feature Layer Collection owner:DublinOhio>,
#  <Item title:"WiFi AP Edit" type:Feature Layer Collection owner:DublinOhio>,
#  <Item title:"Traffic Signal Cntrl Cabinets Edit" type:Feature Layer Collection owner:DublinOhio>,
#  <Item title:"Street Trees Edit" type:Feature Layer Collection owner:DublinOhio>,
#  <Item title:"Subdivisions Edit" type:Feature Layer Collection owner:DublinOhio>,
#  <Item title:"Neighborhoods Edit" type:Feature Layer Collection owner:DublinOhio>,
#  <Item title:"Crashes Edit" type:Feature Layer Collection owner:DublinOhio>,
#  <Item title:"Bikeways Future Planning Edit" type:Feature Layer Collection owner:DublinOhio>,
#  <Item title:"Bikeways Edit" type:Feature Layer Collection owner:DublinOhio>,
#  <Item title:"Crosswalks Edit" type:Feature Layer Collection owner:DublinOhio>,
#  <Item title:"Event Significant Points Edit" type:Feature Layer Collection owner:DublinOhio>,
#  <Item title:"Memorial Tournament Street Signs Edit (HFL)" type:Feature Layer Collection owner:DublinOhio>,
#  <Item title:"Street Light Controllers Edit" type:Feature Layer Collection owner:DublinOhio>,
#  <Item title:"Street Lights Edit" type:Feature Layer Collection owner:DublinOhio>,
#  <Item title:"Sanitary Sewer Edit" type:Feature Layer Collection owner:DublinOhio>,
#  <Item title:"TEST Water Features_Edit" type:Feature Layer Collection owner:DublinOhio>,
#  <Item title:"Damage Assessment Edit" type:Feature Layer Collection owner:DublinOhio>,
#  <Item title:"Aerial Grid 2018 Edit" type:Feature Layer Collection owner:DublinOhio>,
#  <Item title:"Sanitary Flow Meters Edit" type:Feature Layer Collection owner:DublinOhio>,
#  <Item title:"Guardrails Edit" type:Feature Layer Collection owner:DublinOhio>,
#  <Item title:"Signature Event Restroom Locations Edit" type:Feature Layer Collection owner:DublinOhio>,
#  <Item title:"Bridge Street District Street Network Edit" type:Feature Layer Collection owner:DublinOhio>,
#  <Item title:"Curbs Edit" type:Feature Layer Collection owner:DublinOhio>,
#  <Item title:"Smart Mobility Areas Edit" type:Feature Layer Collection owner:DublinOhio>,
#  <Item title:"Sidewalks Edit" type:Feature Layer Collection owner:DublinOhio>,
#  <Item title:"Stream Outfalls Edit" type:Feature Layer Collection owner:DublinOhio>,
#  <Item title:"Aerial Photo Extent Edit" type:Feature Layer Collection owner:DublinOhio>,
#  <Item title:"Existing Land Use 2012 Edit (Current Production)" type:Feature Layer Collection owner:DublinOhio>,
#  <Item title:"Census Blocks 2010 Edit" type:Feature Layer Collection owner:DublinOhio>,
#  <Item title:"Traffic Signal Fiber Edit" type:Feature Layer Collection owner:DublinOhio>,
#  <Item title:"Pavement Striping Edit" type:Feature Layer Collection owner:DublinOhio>,
#  <Item title:"Utility Revenue Sharing Areas Edit" type:Feature Layer Collection owner:DublinOhio>,
#  <Item title:"Cemeteries Edit" type:Feature Layer Collection owner:DublinOhio>,
#  <Item title:"St Signs Small Golf Tournament Edit" type:Feature Layer Collection owner:rfrantz@dublin.oh.us_DublinOhio>,
#  <Item title:"Aerial Grid 2005 to 2007 Edit" type:Feature Layer Collection owner:DublinOhio>,
#  <Item title:"Citizen U Edit" type:Feature Layer Collection owner:DublinOhio>,
#  <Item title:"Electric Circuit Areas Edit" type:Feature Layer Collection owner:DublinOhio>,
#  <Item title:"Memorial Grid Edit" type:Feature Layer Collection owner:DublinOhio>,
#  <Item title:"Soils Edit" type:Feature Layer Collection owner:DublinOhio>,
#  <Item title:"Recreation Points of Interest Edit" type:Feature Layer Collection owner:DublinOhio>,
#  <Item title:"Parcels Edit" type:Feature Layer Collection owner:DublinOhio>,
#  <Item title:"County Permissive Tax Roads Edit" type:Feature Layer Collection owner:DublinOhio>,
#  <Item title:"Art In Public Places Edit" type:Feature Layer Collection owner:DublinOhio>,
#  <Item title:"Code Enforcement Landscape Notes Edit" type:Feature Layer Collection owner:DublinOhio>,
#  <Item title:"Dublink Edit" type:Feature Layer Collection owner:DublinOhio>,
#  <Item title:"2003 Aerial Grid Edit" type:Feature Layer Collection owner:DublinOhio>,
#  <Item title:"Signature Event Tents Edit" type:Feature Layer Collection owner:DublinOhio>,
#  <Item title:"Counties Edit" type:Feature Layer Collection owner:DublinOhio>,
#  <Item title:"Pavement Markings Edit" type:Feature Layer Collection owner:DublinOhio>,
#  <Item title:"Tree Canopy 2010" type:Feature Layer Collection owner:DublinOhio>,
#  <Item title:"Elementary Attendance Areas" type:Feature Layer Collection owner:DublinOhio>,
#  <Item title:"Memorial Tournament Street Signs Install (HFL Edit Att)" type:Feature Layer Collection owner:DublinOhio>,
#  <Item title:"Leaf Truck Tracker Edit" type:Feature Layer Collection owner:DublinOhio>,
#  <Item title:"Dublink Buildings Edit" type:Feature Layer Collection owner:DublinOhio>,
#  <Item title:"Emergency Detour Deployments Edit" type:Feature Layer Collection owner:DublinOhio>,
#  <Item title:"Bikeway Tunnels Edit" type:Feature Layer Collection owner:rjtaylor@dublin.oh.us_DublinOhio>,
#  <Item title:"Curb Ramps Edit" type:Feature Layer Collection owner:DublinOhio>,
#  <Item title:"Address Grid Edit" type:Feature Layer Collection owner:DublinOhio>,
#  <Item title:"Traffic Signal Fiber Intersect Points Edit" type:Feature Layer Collection owner:DublinOhio>,
#  <Item title:"Dublin Parks Edit" type:Feature Layer Collection owner:DublinOhio>,
#  <Item title:"Code Enforcement Special Projects Edit" type:Feature Layer Collection owner:DublinOhio>,
#  <Item title:"Area Attractions Edit" type:Feature Layer Collection owner:DublinOhio>,
#  <Item title:"Streets Polygon Fill Edit" type:Feature Layer Collection owner:DublinOhio>,
#  <Item title:"Bike Racks Edit" type:Feature Layer Collection owner:DublinOhio>,
#  <Item title:"Regional Fiber Edit" type:Feature Layer Collection owner:DublinOhio>,
#  <Item title:"Council Wards Edit" type:Feature Layer Collection owner:DublinOhio>,
#  <Item title:"Future Fiber Edit" type:Feature Layer Collection owner:DublinOhio>,
#  <Item title:"Pavement Historic Repairs Edit" type:Feature Layer Collection owner:DublinOhio>,
#  <Item title:"Streams Edit" type:Feature Layer Collection owner:DublinOhio>,
#  <Item title:"TEST Water Features" type:Feature Layer Collection owner:DublinOhio>,
#  <Item title:"Lighting Edit" type:Feature Layer Collection owner:DublinOhio>,
#  <Item title:"Flag Poles Edit" type:Feature Layer Collection owner:DublinOhio>,
#  <Item title:"Street Map Grid Edit" type:Feature Layer Collection owner:DublinOhio>,
#  <Item title:"Sea Monsters Edit" type:Feature Layer Collection owner:DublinOhio>,
#  <Item title:"School Speed Zones Edit" type:Feature Layer Collection owner:DublinOhio>,
#  <Item title:"Intersections Edit Copied" type:Feature Layer Collection owner:DublinOhio>,
#  <Item title:"Water Features Edit" type:Feature Layer Collection owner:DublinOhio>,
#  <Item title:"Bike Fix-It Stations Edit" type:Feature Layer Collection owner:DublinOhio>,
#  <Item title:"Trash Cans Edit" type:Feature Layer Collection owner:DublinOhio>,
#  <Item title:"Memoria Tournament Pre Event Signage Edit" type:Feature Layer Collection owner:DublinOhio>,
#  <Item title:"Snow Routes (Pavement view)" type:Feature Layer Collection owner:rjtaylor@dublin.oh.us_DublinOhio>,
#  <Item title:"Speed Surveys Edit" type:Feature Layer Collection owner:twawszkiewicz@dublin.oh.us_DublinOhio>,
#  <Item title:"Parking Lots Edit" type:Feature Layer Collection owner:DublinOhio>,
#  <Item title:"DORA Points of Interest Edit" type:Feature Layer Collection owner:DublinOhio>,
#  <Item title:"Agreement Areas Edit" type:Feature Layer Collection owner:DublinOhio>,
#  <Item title:"Subdivisions Attribute Editor" type:Feature Layer Collection owner:DublinOhio>,
#  <Item title:"DEWS Edit" type:Feature Layer Collection owner:DublinOhio>,
#  <Item title:"2009 Aerial Grid Edit" type:Feature Layer Collection owner:DublinOhio>,
#  <Item title:"Wetlands Edit" type:Feature Layer Collection owner:DublinOhio>,
#  <Item title:"School Attendance Areas Edit" type:Feature Layer Collection owner:DublinOhio>,
#  <Item title:"Schools Edit" type:Feature Layer Collection owner:DublinOhio>,
#  <Item title:"Sanitary Sewer Breaks Edit" type:Feature Layer Collection owner:DublinOhio>,
#  <Item title:"DORA - Edit" type:Feature Layer Collection owner:DublinOhio>,
#  <Item title:"Annexation History Edit" type:Feature Layer Collection owner:DublinOhio>,
#  <Item title:"Event Signs Install Order Edit" type:Feature Layer Collection owner:DublinOhio>,
#  <Item title:"Archeological Sites Edit" type:Feature Layer Collection owner:DublinOhio>,
#  <Item title:"Memorial Tournament Course Signage Edit" type:Feature Layer Collection owner:DublinOhio>,
#  <Item title:"Gateways Edit" type:Feature Layer Collection owner:DublinOhio>,
#  <Item title:"Woodlots Edit" type:Feature Layer Collection owner:DublinOhio>,
#  <Item title:"River Edit" type:Feature Layer Collection owner:DublinOhio>,
#  <Item title:"SanitaryLayersForOUPS_PreEdits" type:Feature Layer Collection owner:DublinOhio>,
#  <Item title:"Railroads Edit" type:Feature Layer Collection owner:DublinOhio>,
#  <Item title:"Metro Occupancy Rates Edit" type:Feature Layer Collection owner:DublinOhio>,
#  <Item title:"2011 Aerial Grid Edit" type:Feature Layer Collection owner:DublinOhio>,
#  <Item title:"EMA Event Line Edit" type:Feature Layer Collection owner:DublinOhio>,
#  <Item title:"Parking Restrictions Edit" type:Feature Layer Collection owner:DublinOhio>,
#  <Item title:"Memorial Barriers Edit" type:Feature Layer Collection owner:DublinOhio>,
#  <Item title:"Memorial Cones Edit" type:Feature Layer Collection owner:DublinOhio>,
#  <Item title:"Smart Mobility Hubs Edit" type:Feature Layer Collection owner:DublinOhio>,
#  <Item title:"Event Signage Install" type:Feature Layer Collection owner:DublinOhio>,
#  <Item title:"City Property Edit" type:Feature Layer Collection owner:DublinOhio>,
#  <Item title:"Water Pressure Districts Edit" type:Feature Layer Collection owner:DublinOhio>,
#  <Item title:"Electric Lines Edit" type:Feature Layer Collection owner:DublinOhio>,
#  <Item title:"Recreation Facilities Edit" type:Feature Layer Collection owner:DublinOhio>,
#  <Item title:"Playgrounds Edit" type:Feature Layer Collection owner:DublinOhio>,
#  <Item title:"Irrigation Points Edit" type:Feature Layer Collection owner:DublinOhio>,
#  <Item title:"Memoria Tournament Pre-Event Signage" type:Feature Layer Collection owner:DublinOhio>,
#  <Item title:"Pavement Edit Attribute Only" type:Feature Layer Collection owner:rjtaylor@dublin.oh.us_DublinOhio>,
#  <Item title:"Utility Extension Areas Edit" type:Feature Layer Collection owner:DublinOhio>,
#  <Item title:"Pavement Edit" type:Feature Layer Collection owner:rjtaylor@dublin.oh.us_DublinOhio>,
#  <Item title:"Sirens Edit" type:Feature Layer Collection owner:DublinOhio>,
#  <Item title:"Electronic Signage Edit" type:Feature Layer Collection owner:DublinOhio>,
#  <Item title:"Dublin 3D Buildings" type:Feature Layer Collection owner:DublinOhio>,
#  <Item title:"Future Streets Edit" type:Feature Layer Collection owner:DublinOhio>,
#  <Item title:"Middle School Attendance Areas" type:Feature Layer Collection owner:DublinOhio>,
#  <Item title:"Street Lights Other Edit" type:Feature Layer Collection owner:DublinOhio>,
#  <Item title:"Leaf Streets Edit" type:Feature Layer Collection owner:DublinOhio>,
#  <Item title:"TIF Parcels Edit" type:Feature Layer Collection owner:DublinOhio>,
#  <Item title:"Memorial Parking Lots Edit" type:Feature Layer Collection owner:DublinOhio>,
#  <Item title:"Entry Exit Counter Edit" type:Feature Layer Collection owner:DublinOhio>,
#  <Item title:"Traffic Signal Loop Detectors Edit" type:Feature Layer Collection owner:DublinOhio>,
#  <Item title:"Birdboxes Edit" type:Feature Layer Collection owner:DublinOhio>,
#  <Item title:"Traffic Signals Edit" type:Feature Layer Collection owner:DublinOhio>,
#  <Item title:"Census Tracts 2010 Edit" type:Feature Layer Collection owner:DublinOhio>,
#  <Item title:"Bridges Edit" type:Feature Layer Collection owner:DublinOhio>,
#  <Item title:"Event Boundaries Area Edit" type:Feature Layer Collection owner:DublinOhio>,
#  <Item title:"Points of Interest Edit" type:Feature Layer Collection owner:DublinOhio>]

# %%
backups = backupItems(bkupList,  bkupFolder = "GIS Layers Backups")
# Out:
# Timestamp is 20240611T183510
# Exporting 220 items to destination GIS Layers Backups
#
#
# Processing item:  <Item title:"Zipcodes Edit" type:Feature Layer Collection owner:DublinOhio> ID:  <Item title:"Zipcodes Edit" type:Feature Layer Collection owner:DublinOhio>
# 	Exporting item
# 	Exporting item complete
# 	Moving item to GIS Layers Backups
# Failed to move item
# 	Item 1 of total 220 complete
# 	ID of backup 44c3a7d01c9d49ce9256205b7f7dbf98
#
# ******
#
# Processing item:  <Item title:"Capital Improvement Projects Edit" type:Feature Layer Collection owner:DublinOhio> ID:  <Item title:"Capital Improvement Projects Edit" type:Feature Layer Collection owner:DublinOhio>
# 	Exporting item
# 	Exporting item complete
# 	Moving item to GIS Layers Backups
# Failed to move item
# 	Item 2 of total 220 complete
# 	ID of backup 7d26ad4759c4420ca08185c3cb503e46
#
# ******
#
# Processing item:  <Item title:"Walls Edit" type:Feature Layer Collection owner:DublinOhio> ID:  <Item title:"Walls Edit" type:Feature Layer Collection owner:DublinOhio>
# 	Exporting item
# 	Exporting item complete
# 	Moving item to GIS Layers Backups
# Failed to move item
# 	Item 3 of total 220 complete
# 	ID of backup e81a808430ae4ce49aa852a651b56751
#
# ******
#
# Processing item:  <Item title:"Subdivision Sections Edit" type:Feature Layer Collection owner:DublinOhio> ID:  <Item title:"Subdivision Sections Edit" type:Feature Layer Collection owner:DublinOhio>
# 	Exporting item
# 	Exporting item complete
# 	Moving item to GIS Layers Backups
# Failed to move item
# 	Item 4 of total 220 complete
# 	ID of backup c5d3124a55f44e55a37debf8cd25926c
#
# ******
#
# Processing item:  <Item title:"Tree Canopy Detail Edit" type:Feature Layer Collection owner:DublinOhio> ID:  <Item title:"Tree Canopy Detail Edit" type:Feature Layer Collection owner:DublinOhio>
# 	Exporting item
# 	Exporting item complete
# 	Moving item to GIS Layers Backups
# Failed to move item
# 	Item 5 of total 220 complete
# 	ID of backup 67fb36da20fc41089e6a4c351d28a003
#
# ******
#
# Processing item:  <Item title:"Culverts Edit" type:Feature Layer Collection owner:DublinOhio> ID:  <Item title:"Culverts Edit" type:Feature Layer Collection owner:DublinOhio>
# 	Exporting item
# 	Exporting item complete
# 	Moving item to GIS Layers Backups
# Failed to move item
# 	Item 6 of total 220 complete
# 	ID of backup da353686f11843c48a7687d1b0d5dab5
#
# ******
#
# Processing item:  <Item title:"Emergency Detour Routes Edit" type:Feature Layer Collection owner:DublinOhio> ID:  <Item title:"Emergency Detour Routes Edit" type:Feature Layer Collection owner:DublinOhio>
# 	Exporting item
# 	Exporting item complete
# 	Moving item to GIS Layers Backups
# Failed to move item
# 	Item 7 of total 220 complete
# 	ID of backup a91978dc4c074beeac64808a76431320
#
# ******
#
# Processing item:  <Item title:"Floodplain Historic 2007 Edit" type:Feature Layer Collection owner:DublinOhio> ID:  <Item title:"Floodplain Historic 2007 Edit" type:Feature Layer Collection owner:DublinOhio>
# 	Exporting item
# 	Exporting item complete
# 	Moving item to GIS Layers Backups
# Failed to move item
# 	Item 8 of total 220 complete
# 	ID of backup c37d0aa314bd4bcbb1c7cf15b1b939a7
#
# ******
#
# Processing item:  <Item title:"EMA Event Area Edit" type:Feature Layer Collection owner:DublinOhio> ID:  <Item title:"EMA Event Area Edit" type:Feature Layer Collection owner:DublinOhio>
# 	Exporting item
# 	Exporting item complete
# 	Moving item to GIS Layers Backups
# Failed to move item
# 	Item 9 of total 220 complete
# 	ID of backup 194eca0ba3cb4a4da3df575a55348fda
#
# ******
#
# Processing item:  <Item title:"Backwater Valve Inventory Edit" type:Feature Layer Collection owner:DublinOhio> ID:  <Item title:"Backwater Valve Inventory Edit" type:Feature Layer Collection owner:DublinOhio>
# 	Exporting item
# 	Exporting item complete
# 	Moving item to GIS Layers Backups
# Failed to move item
# 	Item 10 of total 220 complete
# 	ID of backup 9e6574e4190140999d4baabe3e1bb031
#
# ******
#
# Processing item:  <Item title:"Crashes Edit Copied" type:Feature Layer Collection owner:DublinOhio> ID:  <Item title:"Crashes Edit Copied" type:Feature Layer Collection owner:DublinOhio>
# 	Exporting item
# 	Exporting item complete
# 	Moving item to GIS Layers Backups
# Failed to move item
# 	Item 11 of total 220 complete
# 	ID of backup 5aca8d4404324d4fb5c86b030a2b6bd7
#
# ******
#
# Processing item:  <Item title:"Landscaping Contracts Edit" type:Feature Layer Collection owner:DublinOhio> ID:  <Item title:"Landscaping Contracts Edit" type:Feature Layer Collection owner:DublinOhio>
# 	Exporting item
# 	Exporting item complete
# 	Moving item to GIS Layers Backups
# Failed to move item
# 	Item 12 of total 220 complete
# 	ID of backup fe8787f76bc94b6188fef9c9c5bd5462
#
# ******
#
# Processing item:  <Item title:"CVT Edit" type:Feature Layer Collection owner:DublinOhio> ID:  <Item title:"CVT Edit" type:Feature Layer Collection owner:DublinOhio>
# 	Exporting item
# 	Exporting item complete
# 	Moving item to GIS Layers Backups
# Failed to move item
# 	Item 13 of total 220 complete
# 	ID of backup 3c402b49332d430c9c84fa1c78eb0415
#
# ******
#
# Processing item:  <Item title:"Edit Mule" type:Feature Layer Collection owner:DublinOhio> ID:  <Item title:"Edit Mule" type:Feature Layer Collection owner:DublinOhio>
# 	Exporting item
# 	Exporting item complete
# 	Moving item to GIS Layers Backups
# Failed to move item
# 	Item 14 of total 220 complete
# 	ID of backup 5c2bfa6cea324d468ff6435e66b52fe8
#
# ******
#
# Processing item:  <Item title:"Other Bikeways Edit" type:Feature Layer Collection owner:DublinOhio> ID:  <Item title:"Other Bikeways Edit" type:Feature Layer Collection owner:DublinOhio>
# 	Exporting item
# 	Exporting item complete
# 	Moving item to GIS Layers Backups
# Failed to move item
# 	Item 15 of total 220 complete
# 	ID of backup 16b1e887397143409532c15fd70f0cc6
#
# ******
#
# Processing item:  <Item title:"High School Attendance Areas" type:Feature Layer Collection owner:DublinOhio> ID:  <Item title:"High School Attendance Areas" type:Feature Layer Collection owner:DublinOhio>
# 	Exporting item
# 	Exporting item complete
# 	Moving item to GIS Layers Backups
# Failed to move item
# 	Item 16 of total 220 complete
# 	ID of backup 641f11c086574106ae6fab2bfcb01ab7
#
# ******
#
# Processing item:  <Item title:"Traffic Signal Poles Edit" type:Feature Layer Collection owner:DublinOhio> ID:  <Item title:"Traffic Signal Poles Edit" type:Feature Layer Collection owner:DublinOhio>
# 	Exporting item
# 	Exporting item complete
# 	Moving item to GIS Layers Backups
# Failed to move item
# 	Item 17 of total 220 complete
# 	ID of backup 16ef97945cb447ffb4e967ba11d54a47
#
# ******
#
# Processing item:  <Item title:"Water Utility Edit" type:Feature Layer Collection owner:DublinOhio> ID:  <Item title:"Water Utility Edit" type:Feature Layer Collection owner:DublinOhio>
# 	Exporting item
# 	Exporting item complete
# 	Moving item to GIS Layers Backups
# Failed to move item
# 	Item 18 of total 220 complete
# 	ID of backup b021f62c83a04585bda28b1bdda9b595
#
# ******
#
# Processing item:  <Item title:"Memorial Tournament Parking Lot and Street No Parking Signage Edit" type:Feature Layer Collection owner:DublinOhio> ID:  <Item title:"Memorial Tournament Parking Lot and Street No Parking Signage Edit" type:Feature Layer Collection owner:DublinOhio>
# 	Exporting item
# 	Exporting item complete
# 	Moving item to GIS Layers Backups
# Failed to move item
# 	Item 19 of total 220 complete
# 	ID of backup 9478d95739064f0d9029cb0962f7d196
#
# ******
#
# Processing item:  <Item title:"DORA Businesses Edit" type:Feature Layer Collection owner:DublinOhio> ID:  <Item title:"DORA Businesses Edit" type:Feature Layer Collection owner:DublinOhio>
# 	Exporting item
# 	Exporting item complete
# 	Moving item to GIS Layers Backups
# Failed to move item
# 	Item 20 of total 220 complete
# 	ID of backup a18c3af856fa4653bf3853d8ec5106be
#
# ******
#
# Processing item:  <Item title:"Zoning Edit" type:Feature Layer Collection owner:DublinOhio> ID:  <Item title:"Zoning Edit" type:Feature Layer Collection owner:DublinOhio>
# 	Exporting item
# 	Exporting item complete
# 	Moving item to GIS Layers Backups
# Failed to move item
# 	Item 21 of total 220 complete
# 	ID of backup a2b463e1ad034100aa6969ff013834a9
#
# ******
#
# Processing item:  <Item title:"Event Signage Edit" type:Feature Layer Collection owner:DublinOhio> ID:  <Item title:"Event Signage Edit" type:Feature Layer Collection owner:DublinOhio>
# 	Exporting item
# 	Exporting item complete
# 	Moving item to GIS Layers Backups
# Failed to move item
# 	Item 22 of total 220 complete
# 	ID of backup b8614f95a9dd4dafb6d2787245dc2d52
#
# ******
#
# Processing item:  <Item title:"City Facilities Edit" type:Feature Layer Collection owner:DublinOhio> ID:  <Item title:"City Facilities Edit" type:Feature Layer Collection owner:DublinOhio>
# 	Exporting item
# 	Exporting item complete
# 	Moving item to GIS Layers Backups
# Failed to move item
# 	Item 23 of total 220 complete
# 	ID of backup 958cd5d22ce44fe582ce7bd323601152
#
# ******
#
# Processing item:  <Item title:"Ward_Boundary_Work_Neigh_Validate" type:Feature Layer Collection owner:DublinOhio> ID:  <Item title:"Ward_Boundary_Work_Neigh_Validate" type:Feature Layer Collection owner:DublinOhio>
# 	Exporting item
# 	Exporting item complete
# 	Moving item to GIS Layers Backups
# Failed to move item
# 	Item 24 of total 220 complete
# 	ID of backup fff339c48152401989786e6cdb9f356f
#
# ******
#
# Processing item:  <Item title:"EMA Structure Inspection Edit" type:Feature Layer Collection owner:DublinOhio> ID:  <Item title:"EMA Structure Inspection Edit" type:Feature Layer Collection owner:DublinOhio>
# 	Exporting item
# 	Exporting item complete
# 	Moving item to GIS Layers Backups
# Failed to move item
# 	Item 25 of total 220 complete
# 	ID of backup 2ab61957e8824a1497e5ba7192e2a110
#
# ******
#
# Processing item:  <Item title:"Bridge Street District Non-Study Area Edit" type:Feature Layer Collection owner:DublinOhio> ID:  <Item title:"Bridge Street District Non-Study Area Edit" type:Feature Layer Collection owner:DublinOhio>
# 	Exporting item
# 	Exporting item complete
# 	Moving item to GIS Layers Backups
# Failed to move item
# 	Item 26 of total 220 complete
# 	ID of backup f7a90fcb4b244e658e957b6e69d60b09
#
# ******
#
# Processing item:  <Item title:"Floodplain Edit" type:Feature Layer Collection owner:DublinOhio> ID:  <Item title:"Floodplain Edit" type:Feature Layer Collection owner:DublinOhio>
# 	Exporting item
# 	Exporting item complete
# 	Moving item to GIS Layers Backups
# Failed to move item
# 	Item 27 of total 220 complete
# 	ID of backup 78f768b8bed542c5b9a791bc36a6b72c
#
# ******
#
# Processing item:  <Item title:"Bridge Street District Study Area Edit" type:Feature Layer Collection owner:DublinOhio> ID:  <Item title:"Bridge Street District Study Area Edit" type:Feature Layer Collection owner:DublinOhio>
# 	Exporting item
# 	Exporting item complete
# 	Moving item to GIS Layers Backups
# Failed to move item
# 	Item 28 of total 220 complete
# 	ID of backup 66af667e7d5b4e009860f1af48c9002c
#
# ******
#
# Processing item:  <Item title:"EMA Event Point Edit" type:Feature Layer Collection owner:DublinOhio> ID:  <Item title:"EMA Event Point Edit" type:Feature Layer Collection owner:DublinOhio>
# 	Exporting item
# 	Exporting item complete
# 	Moving item to GIS Layers Backups
# Failed to move item
# 	Item 29 of total 220 complete
# 	ID of backup 66229e25b64b4516baf894cc24576ba1
#
# ******
#
# Processing item:  <Item title:"Electric Poles Edit" type:Feature Layer Collection owner:DublinOhio> ID:  <Item title:"Electric Poles Edit" type:Feature Layer Collection owner:DublinOhio>
# 	Exporting item
# 	Exporting item complete
# 	Moving item to GIS Layers Backups
# Failed to move item
# 	Item 30 of total 220 complete
# 	ID of backup 97071532163c4ecfa7c39e76ea297691
#
# ******
#
# Processing item:  <Item title:"DIF Grid Edit" type:Feature Layer Collection owner:DublinOhio> ID:  <Item title:"DIF Grid Edit" type:Feature Layer Collection owner:DublinOhio>
# 	Exporting item
# 	Exporting item complete
# 	Moving item to GIS Layers Backups
# Failed to move item
# 	Item 31 of total 220 complete
# 	ID of backup d49dc5af34a34f1384a6305aa2c961c5
#
# ******
#
# Processing item:  <Item title:"Census Block Groups 2010 Edit" type:Feature Layer Collection owner:DublinOhio> ID:  <Item title:"Census Block Groups 2010 Edit" type:Feature Layer Collection owner:DublinOhio>
# 	Exporting item
# 	Exporting item complete
# 	Moving item to GIS Layers Backups
# Failed to move item
# 	Item 32 of total 220 complete
# 	ID of backup 93fff536d71340bcab8d6a5e4aa369e8
#
# ******
#
# Processing item:  <Item title:"Scenic Roads Edit" type:Feature Layer Collection owner:DublinOhio> ID:  <Item title:"Scenic Roads Edit" type:Feature Layer Collection owner:DublinOhio>
# 	Exporting item
# 	Exporting item complete
# 	Moving item to GIS Layers Backups
# Failed to move item
# 	Item 33 of total 220 complete
# 	ID of backup c278829364d2426b9f41114309b72cf3
#
# ******
#
# Processing item:  <Item title:"Deer Auto Collisions Edit" type:Feature Layer Collection owner:DublinOhio> ID:  <Item title:"Deer Auto Collisions Edit" type:Feature Layer Collection owner:DublinOhio>
# 	Exporting item
# 	Exporting item complete
# 	Moving item to GIS Layers Backups
# Failed to move item
# 	Item 34 of total 220 complete
# 	ID of backup 87a523c391454e17810d2b9529fc6e8c
#
# ******
#
# Processing item:  <Item title:"Cache Update Boundary Edit" type:Feature Layer Collection owner:DublinOhio> ID:  <Item title:"Cache Update Boundary Edit" type:Feature Layer Collection owner:DublinOhio>
# 	Exporting item
# 	Exporting item complete
# 	Moving item to GIS Layers Backups
# Failed to move item
# 	Item 35 of total 220 complete
# 	ID of backup d1c3e6b1a84248d7a99a2b28e2d42cb1
#
# ******
#
# Processing item:  <Item title:"Other Parks Edit" type:Feature Layer Collection owner:DublinOhio> ID:  <Item title:"Other Parks Edit" type:Feature Layer Collection owner:DublinOhio>
# 	Exporting item
# 	Exporting item complete
# 	Moving item to GIS Layers Backups
# Failed to move item
# 	Item 36 of total 220 complete
# 	ID of backup 3a9a8691ff8647a1abea1ced635ae248
#
# ******
#
# Processing item:  <Item title:"Number of Lanes Edit" type:Feature Layer Collection owner:DublinOhio> ID:  <Item title:"Number of Lanes Edit" type:Feature Layer Collection owner:DublinOhio>
# 	Exporting item
# 	Exporting item complete
# 	Moving item to GIS Layers Backups
# Failed to move item
# 	Item 37 of total 220 complete
# 	ID of backup 9e04654a49a141db9b17e92fdd92a5d4
#
# ******
#
# Processing item:  <Item title:"Cultural Assessment Structures Edit" type:Feature Layer Collection owner:DublinOhio> ID:  <Item title:"Cultural Assessment Structures Edit" type:Feature Layer Collection owner:DublinOhio>
# 	Exporting item
# 	Exporting item complete
# 	Moving item to GIS Layers Backups
# Failed to move item
# 	Item 38 of total 220 complete
# 	ID of backup 06ffabf5b70b4ac7a963d8c9b0457351
#
# ******
#
# Processing item:  <Item title:"Bedrock Edit" type:Feature Layer Collection owner:DublinOhio> ID:  <Item title:"Bedrock Edit" type:Feature Layer Collection owner:DublinOhio>
# 	Exporting item
# 	Exporting item complete
# 	Moving item to GIS Layers Backups
# Failed to move item
# 	Item 39 of total 220 complete
# 	ID of backup 5a596a158b6444d68fdc3efed0646b92
#
# ******
#
# Processing item:  <Item title:"Decks Docks Stairs Edit" type:Feature Layer Collection owner:rjtaylor@dublin.oh.us_DublinOhio> ID:  <Item title:"Decks Docks Stairs Edit" type:Feature Layer Collection owner:rjtaylor@dublin.oh.us_DublinOhio>
# 	Exporting item
# 	Exporting item complete
# 	Moving item to GIS Layers Backups
# Failed to move item
# 	Item 40 of total 220 complete
# 	ID of backup 139411dd50604b07a1bdd71f9e51b7b0
#
# ******
#
# Processing item:  <Item title:"Commercial Trees Edit" type:Feature Layer Collection owner:DublinOhio> ID:  <Item title:"Commercial Trees Edit" type:Feature Layer Collection owner:DublinOhio>
# 	Exporting item
# 	Exporting item complete
# 	Moving item to GIS Layers Backups
# Failed to move item
# 	Item 41 of total 220 complete
# 	ID of backup c3dd34d8b18d4553a266139dbd85fa23
#
# ******
#
# Processing item:  <Item title:"Restroom Facilities Edit" type:Feature Layer Collection owner:DublinOhio> ID:  <Item title:"Restroom Facilities Edit" type:Feature Layer Collection owner:DublinOhio>
# 	Exporting item
# 	Exporting item complete
# 	Moving item to GIS Layers Backups
# Failed to move item
# 	Item 42 of total 220 complete
# 	ID of backup c3be2723b37d41429293e03f563aee29
#
# ******
#
# Processing item:  <Item title:"Other Agreement Areas Edit" type:Feature Layer Collection owner:DublinOhio> ID:  <Item title:"Other Agreement Areas Edit" type:Feature Layer Collection owner:DublinOhio>
# 	Exporting item
# 	Exporting item complete
# 	Moving item to GIS Layers Backups
# Failed to move item
# 	Item 43 of total 220 complete
# 	ID of backup 4a69fd44be9f4a4db002e8f83ffb8ef4
#
# ******
#
# Processing item:  <Item title:"Historic District Structure Info Edit" type:Feature Layer Collection owner:DublinOhio> ID:  <Item title:"Historic District Structure Info Edit" type:Feature Layer Collection owner:DublinOhio>
# 	Exporting item
# 	Exporting item complete
# 	Moving item to GIS Layers Backups
# Failed to move item
# 	Item 44 of total 220 complete
# 	ID of backup c2d9df1f86434a198b173a35727c0cac
#
# ******
#
# Processing item:  <Item title:"Memorial Tournament POI Edit" type:Feature Layer Collection owner:DublinOhio> ID:  <Item title:"Memorial Tournament POI Edit" type:Feature Layer Collection owner:DublinOhio>
# 	Exporting item
# 	Exporting item complete
# 	Moving item to GIS Layers Backups
# Failed to move item
# 	Item 45 of total 220 complete
# 	ID of backup 40c5b39346034e66b8b7710c556b81b6
#
# ******
#
# Processing item:  <Item title:"Floodplain FIRM Panels Edit" type:Feature Layer Collection owner:DublinOhio> ID:  <Item title:"Floodplain FIRM Panels Edit" type:Feature Layer Collection owner:DublinOhio>
# 	Exporting item
# 	Exporting item complete
# 	Moving item to GIS Layers Backups
# Failed to move item
# 	Item 46 of total 220 complete
# 	ID of backup b6cf4acb13f3420b84adfc3394a7c195
#
# ******
#
# Processing item:  <Item title:"Bridge Rails Edit" type:Feature Layer Collection owner:DublinOhio> ID:  <Item title:"Bridge Rails Edit" type:Feature Layer Collection owner:DublinOhio>
# 	Exporting item
# 	Exporting item complete
# 	Moving item to GIS Layers Backups
# Failed to move item
# 	Item 47 of total 220 complete
# 	ID of backup ccdbd17f79234c47a3c44efa759d51d9
#
# ******
#
# Processing item:  <Item title:"Dublin Database" type:Feature Layer Collection owner:DublinOhio> ID:  <Item title:"Dublin Database" type:Feature Layer Collection owner:DublinOhio>
# 	Exporting item
# 	Exporting item complete
# 	Moving item to GIS Layers Backups
# Failed to move item
# 	Item 48 of total 220 complete
# 	ID of backup 84f8f6f06a8243368eb9e7c02a84a35a
#
# ******
#
# Processing item:  <Item title:"Entry Exit Counter" type:Feature Layer Collection owner:DublinOhio> ID:  <Item title:"Entry Exit Counter" type:Feature Layer Collection owner:DublinOhio>
# 	Exporting item
# 	Exporting item complete
# 	Moving item to GIS Layers Backups
# Failed to move item
# 	Item 49 of total 220 complete
# 	ID of backup 33cfedfb5c8441e0b64a4e3b84e4465b
#
# ******
#
# Processing item:  <Item title:"Acquisition Comments Edit" type:Feature Layer Collection owner:DublinOhio> ID:  <Item title:"Acquisition Comments Edit" type:Feature Layer Collection owner:DublinOhio>
# 	Exporting item
# 	Exporting item complete
# 	Moving item to GIS Layers Backups
# Failed to move item
# 	Item 50 of total 220 complete
# 	ID of backup 59726a4de32248399f62211a32a54a0b
#
# ******
#
# Processing item:  <Item title:"Memorial Tournament No Parking Zones Edit" type:Feature Layer Collection owner:DublinOhio> ID:  <Item title:"Memorial Tournament No Parking Zones Edit" type:Feature Layer Collection owner:DublinOhio>
# 	Exporting item
# 	Exporting item complete
# 	Moving item to GIS Layers Backups
# Failed to move item
# 	Item 51 of total 220 complete
# 	ID of backup 6519b024d6484a0689b6a2b8a4c2d7cb
#
# ******
#
# Processing item:  <Item title:"Snow Zones Edit" type:Feature Layer Collection owner:DublinOhio> ID:  <Item title:"Snow Zones Edit" type:Feature Layer Collection owner:DublinOhio>
# 	Exporting item
# 	Exporting item complete
# 	Moving item to GIS Layers Backups
# Failed to move item
# 	Item 52 of total 220 complete
# 	ID of backup b87bd5c9e6d444e79a000239b1fc6688
#
# ******
#
# Processing item:  <Item title:"School Districts Edit" type:Feature Layer Collection owner:DublinOhio> ID:  <Item title:"School Districts Edit" type:Feature Layer Collection owner:DublinOhio>
# 	Exporting item
# 	Exporting item complete
# 	Moving item to GIS Layers Backups
# Failed to move item
# 	Item 53 of total 220 complete
# 	ID of backup 45139f395ba94e7eb2aa33de5cf1ab6b
#
# ******
#
# Processing item:  <Item title:"Service Districts Edit" type:Feature Layer Collection owner:DublinOhio> ID:  <Item title:"Service Districts Edit" type:Feature Layer Collection owner:DublinOhio>
# 	Exporting item
# 	Exporting item complete
# 	Moving item to GIS Layers Backups
# Failed to move item
# 	Item 54 of total 220 complete
# 	ID of backup 4dff8fab554a4bf6b8463ece7776754a
#
# ******
#
# Processing item:  <Item title:"Intersections Edit" type:Feature Layer Collection owner:DublinOhio> ID:  <Item title:"Intersections Edit" type:Feature Layer Collection owner:DublinOhio>
# 	Exporting item
# 	Exporting item complete
# 	Moving item to GIS Layers Backups
# Failed to move item
# 	Item 55 of total 220 complete
# 	ID of backup 4c02ed527c184dae9c6f9506a2224d19
#
# ******
#
# Processing item:  <Item title:"Signs Edit" type:Feature Layer Collection owner:DublinOhio> ID:  <Item title:"Signs Edit" type:Feature Layer Collection owner:DublinOhio>
# 	Exporting item
# 	Exporting item complete
# 	Moving item to GIS Layers Backups
# Failed to move item
# 	Item 56 of total 220 complete
# 	ID of backup 3c3be050704f49318e0729f5743d53f1
#
# ******
#
# Processing item:  <Item title:"Pavement Striping" type:Feature Layer Collection owner:DublinOhio> ID:  <Item title:"Pavement Striping" type:Feature Layer Collection owner:DublinOhio>
# 	Exporting item
# 	Exporting item complete
# 	Moving item to GIS Layers Backups
# Failed to move item
# 	Item 57 of total 220 complete
# 	ID of backup 9fd8a2e0e4cd4704a281dd14f8b19df6
#
# ******
#
# Processing item:  <Item title:"Bikeway Signed Route Edit" type:Feature Layer Collection owner:DublinOhio> ID:  <Item title:"Bikeway Signed Route Edit" type:Feature Layer Collection owner:DublinOhio>
# 	Exporting item
# 	Exporting item complete
# 	Moving item to GIS Layers Backups
# Failed to move item
# 	Item 58 of total 220 complete
# 	ID of backup 1cccc5566545457a8e24dce2f8c52abc
#
# ******
#
# Processing item:  <Item title:"Storm Sewer Edit" type:Feature Layer Collection owner:DublinOhio> ID:  <Item title:"Storm Sewer Edit" type:Feature Layer Collection owner:DublinOhio>
# 	Exporting item
# 	Exporting item complete
# 	Moving item to GIS Layers Backups
# Failed to move item
# 	Item 59 of total 220 complete
# 	ID of backup 724dbc547d5b4bf38df4cc0fe20edd73
#
# ******
#
# Processing item:  <Item title:"Buildings Edit" type:Feature Layer Collection owner:DublinOhio> ID:  <Item title:"Buildings Edit" type:Feature Layer Collection owner:DublinOhio>
# 	Exporting item
# 	Exporting item complete
# 	Moving item to GIS Layers Backups
# Failed to move item
# 	Item 60 of total 220 complete
# 	ID of backup 9afff05ccd314b47a7532862d5462d1b
#
# ******
#
# Processing item:  <Item title:"Community Event Race Routes Equipment Edit" type:Feature Layer Collection owner:DublinOhio> ID:  <Item title:"Community Event Race Routes Equipment Edit" type:Feature Layer Collection owner:DublinOhio>
# 	Exporting item
# 	Exporting item complete
# 	Moving item to GIS Layers Backups
# Failed to move item
# 	Item 61 of total 220 complete
# 	ID of backup 7e914c552db14221acbf2f6053c6aefd
#
# ******
#
# Processing item:  <Item title:"Dublink Regional (Outer Loop and Downtown)" type:Feature Layer Collection owner:DublinOhio> ID:  <Item title:"Dublink Regional (Outer Loop and Downtown)" type:Feature Layer Collection owner:DublinOhio>
# 	Exporting item
# 	Exporting item complete
# 	Moving item to GIS Layers Backups
# Failed to move item
# 	Item 62 of total 220 complete
# 	ID of backup 90d0b07f8f514acd96b1db9592bdaa2c
#
# ******
#
# Processing item:  <Item title:"Storm Mains Fieldwork Edit" type:Feature Layer Collection owner:DublinOhio> ID:  <Item title:"Storm Mains Fieldwork Edit" type:Feature Layer Collection owner:DublinOhio>
# 	Exporting item
# Failed Exporting Item
# 	Moving item to GIS Layers Backups
# Failed to move item
# 	Item 63 of total 220 complete
# 	ID of backup 90d0b07f8f514acd96b1db9592bdaa2c
#
# ******
#
# Processing item:  <Item title:"Cellular Towers Edit" type:Feature Layer Collection owner:DublinOhio> ID:  <Item title:"Cellular Towers Edit" type:Feature Layer Collection owner:DublinOhio>
# 	Exporting item
# Failed Exporting Item
# 	Moving item to GIS Layers Backups
# Failed to move item
# 	Item 64 of total 220 complete
# 	ID of backup 90d0b07f8f514acd96b1db9592bdaa2c
#
# ******
#
# Processing item:  <Item title:"Non-Dublin Area Edit" type:Feature Layer Collection owner:DublinOhio> ID:  <Item title:"Non-Dublin Area Edit" type:Feature Layer Collection owner:DublinOhio>
# 	Exporting item
# 	Exporting item complete
# 	Moving item to GIS Layers Backups
# Failed to move item
# 	Item 65 of total 220 complete
# 	ID of backup 55800aead9fa4282b27b9e0b8aaff2ba
#
# ******
#
# Processing item:  <Item title:"Stream Protection Zone Edit" type:Feature Layer Collection owner:DublinOhio> ID:  <Item title:"Stream Protection Zone Edit" type:Feature Layer Collection owner:DublinOhio>
# 	Exporting item
# 	Exporting item complete
# 	Moving item to GIS Layers Backups
# Failed to move item
# 	Item 66 of total 220 complete
# 	ID of backup daedc68a00a54a71a35b518d0bd5d1af
#
# ******
#
# Processing item:  <Item title:"Independence Day Grid Edit" type:Feature Layer Collection owner:DublinOhio> ID:  <Item title:"Independence Day Grid Edit" type:Feature Layer Collection owner:DublinOhio>
# 	Exporting item
# 	Exporting item complete
# 	Moving item to GIS Layers Backups
# Failed to move item
# 	Item 67 of total 220 complete
# 	ID of backup 9333fd810244435187c91e884bd331e1
#
# ******
#
# Processing item:  <Item title:"Watersheds Edit" type:Feature Layer Collection owner:DublinOhio> ID:  <Item title:"Watersheds Edit" type:Feature Layer Collection owner:DublinOhio>
# 	Exporting item
# 	Exporting item complete
# 	Moving item to GIS Layers Backups
# Failed to move item
# 	Item 68 of total 220 complete
# 	ID of backup 961acd7fa0de415f910d4ff81cd4ce40
#
# ******
#
# Processing item:  <Item title:"Parcel Update Boundary Edit" type:Feature Layer Collection owner:DublinOhio> ID:  <Item title:"Parcel Update Boundary Edit" type:Feature Layer Collection owner:DublinOhio>
# 	Exporting item
# 	Exporting item complete
# 	Moving item to GIS Layers Backups
# Failed to move item
# 	Item 69 of total 220 complete
# 	ID of backup 3fbd0c5f1e6a4c2a936e34caa421a193
#
# ******
#
# Processing item:  <Item title:"Water Main Breaks Edit" type:Feature Layer Collection owner:DublinOhio> ID:  <Item title:"Water Main Breaks Edit" type:Feature Layer Collection owner:DublinOhio>
# 	Exporting item
# 	Exporting item complete
# 	Moving item to GIS Layers Backups
# Failed to move item
# 	Item 70 of total 220 complete
# 	ID of backup b2f9353a990b402fa0914b4b00fc5b31
#
# ******
#
# Processing item:  <Item title:"Cultural Assessment Walls Edit" type:Feature Layer Collection owner:DublinOhio> ID:  <Item title:"Cultural Assessment Walls Edit" type:Feature Layer Collection owner:DublinOhio>
# 	Exporting item
# 	Exporting item complete
# 	Moving item to GIS Layers Backups
# Failed to move item
# 	Item 71 of total 220 complete
# 	ID of backup f5a84c932b3e407fa715e32d65e21060
#
# ******
#
# Processing item:  <Item title:"Floodplain LOMR Edit" type:Feature Layer Collection owner:DublinOhio> ID:  <Item title:"Floodplain LOMR Edit" type:Feature Layer Collection owner:DublinOhio>
# 	Exporting item
# 	Exporting item complete
# 	Moving item to GIS Layers Backups
# Failed to move item
# 	Item 72 of total 220 complete
# 	ID of backup 177eb7b8f29445038f88b90a7bd50707
#
# ******
#
# Processing item:  <Item title:"Medians Edit" type:Feature Layer Collection owner:DublinOhio> ID:  <Item title:"Medians Edit" type:Feature Layer Collection owner:DublinOhio>
# 	Exporting item
# 	Exporting item complete
# 	Moving item to GIS Layers Backups
# Failed to move item
# 	Item 73 of total 220 complete
# 	ID of backup 2f906bdb74fc4ac6b2f7c428b2fd31db
#
# ******
#
# Processing item:  <Item title:"Memorial Tournament Cones Edit" type:Feature Layer Collection owner:DublinOhio> ID:  <Item title:"Memorial Tournament Cones Edit" type:Feature Layer Collection owner:DublinOhio>
# 	Exporting item
# 	Exporting item complete
# 	Moving item to GIS Layers Backups
# Failed to move item
# 	Item 74 of total 220 complete
# 	ID of backup a7fe08e7d4a245008e7d35bd2703a885
#
# ******
#
# Processing item:  <Item title:"City Facilities GoDublin Edit" type:Feature Layer Collection owner:DublinOhio> ID:  <Item title:"City Facilities GoDublin Edit" type:Feature Layer Collection owner:DublinOhio>
# 	Exporting item
# 	Exporting item complete
# 	Moving item to GIS Layers Backups
# Failed to move item
# 	Item 75 of total 220 complete
# 	ID of backup 2f4257c2628f496bbcfaa3444b3b2a91
#
# ******
#
# Processing item:  <Item title:"Future Land Use 2012 Edit (Current Production)" type:Feature Layer Collection owner:DublinOhio> ID:  <Item title:"Future Land Use 2012 Edit (Current Production)" type:Feature Layer Collection owner:DublinOhio>
# 	Exporting item
# 	Exporting item complete
# 	Moving item to GIS Layers Backups
# Failed to move item
# 	Item 76 of total 220 complete
# 	ID of backup 91ef884dff3d45d49749d8a551588cdd
#
# ******
#
# Processing item:  <Item title:"Architectural Review District Edit" type:Feature Layer Collection owner:DublinOhio> ID:  <Item title:"Architectural Review District Edit" type:Feature Layer Collection owner:DublinOhio>
# 	Exporting item
# 	Exporting item complete
# 	Moving item to GIS Layers Backups
# Failed to move item
# 	Item 77 of total 220 complete
# 	ID of backup 92f49db8a84f4badaff780d0ed1bf36b
#
# ******
#
# Processing item:  <Item title:"Dublin Water and Sewer Service Area Edit" type:Feature Layer Collection owner:DublinOhio> ID:  <Item title:"Dublin Water and Sewer Service Area Edit" type:Feature Layer Collection owner:DublinOhio>
# 	Exporting item
# 	Exporting item complete
# 	Moving item to GIS Layers Backups
# Failed to move item
# 	Item 78 of total 220 complete
# 	ID of backup 5db65bda60a34e08b9689ced319d3fbb
#
# ******
#
# Processing item:  <Item title:"Cellular Infrastructure - Edit" type:Feature Layer Collection owner:DublinOhio> ID:  <Item title:"Cellular Infrastructure - Edit" type:Feature Layer Collection owner:DublinOhio>
# 	Exporting item
# 	Exporting item complete
# 	Moving item to GIS Layers Backups
# Failed to move item
# 	Item 79 of total 220 complete
# 	ID of backup 3b385b21b82e4801b62c7efaefba1f1b
#
# ******
#
# Processing item:  <Item title:"Non DEM Area Edit" type:Feature Layer Collection owner:DublinOhio> ID:  <Item title:"Non DEM Area Edit" type:Feature Layer Collection owner:DublinOhio>
# 	Exporting item
# 	Exporting item complete
# 	Moving item to GIS Layers Backups
# Failed to move item
# 	Item 80 of total 220 complete
# 	ID of backup a256a0df8efa49daa6abbb93b92c28c2
#
# ******
#
# Processing item:  <Item title:"Forever Dublin Addresses Edit" type:Feature Layer Collection owner:DublinOhio> ID:  <Item title:"Forever Dublin Addresses Edit" type:Feature Layer Collection owner:DublinOhio>
# 	Exporting item
# 	Exporting item complete
# 	Moving item to GIS Layers Backups
# Failed to move item
# 	Item 81 of total 220 complete
# 	ID of backup 8bd1e1ec77334bd8aef1cd62d544f904
#
# ******
#
# Processing item:  <Item title:"Construction Projects Edit" type:Feature Layer Collection owner:DublinOhio> ID:  <Item title:"Construction Projects Edit" type:Feature Layer Collection owner:DublinOhio>
# 	Exporting item
# 	Exporting item complete
# 	Moving item to GIS Layers Backups
# Failed to move item
# 	Item 82 of total 220 complete
# 	ID of backup d1eda21e4d6f4b6e8aad38149faa0fe8
#
# ******
#
# Processing item:  <Item title:"Irrigation Lines Edit" type:Feature Layer Collection owner:DublinOhio> ID:  <Item title:"Irrigation Lines Edit" type:Feature Layer Collection owner:DublinOhio>
# 	Exporting item
# 	Exporting item complete
# 	Moving item to GIS Layers Backups
# Failed to move item
# 	Item 83 of total 220 complete
# 	ID of backup e9ce5e8e3bad4eb1b1c3d31140faa858
#
# ******
#
# Processing item:  <Item title:"Indian Mounds Edit" type:Feature Layer Collection owner:DublinOhio> ID:  <Item title:"Indian Mounds Edit" type:Feature Layer Collection owner:DublinOhio>
# 	Exporting item
# 	Exporting item complete
# 	Moving item to GIS Layers Backups
# Failed to move item
# 	Item 84 of total 220 complete
# 	ID of backup 13b198656b624eceb1dd091aa92a8341
#
# ******
#
# Processing item:  <Item title:"WiFi AP Edit" type:Feature Layer Collection owner:DublinOhio> ID:  <Item title:"WiFi AP Edit" type:Feature Layer Collection owner:DublinOhio>
# 	Exporting item
# 	Exporting item complete
# 	Moving item to GIS Layers Backups
# Failed to move item
# 	Item 85 of total 220 complete
# 	ID of backup 617f5eaf143844cd9570a88820891eea
#
# ******
#
# Processing item:  <Item title:"Traffic Signal Cntrl Cabinets Edit" type:Feature Layer Collection owner:DublinOhio> ID:  <Item title:"Traffic Signal Cntrl Cabinets Edit" type:Feature Layer Collection owner:DublinOhio>
# 	Exporting item
# 	Exporting item complete
# 	Moving item to GIS Layers Backups
# Failed to move item
# 	Item 86 of total 220 complete
# 	ID of backup 0c53e6c9d13141a7997473db8b2bdd10
#
# ******
#
# Processing item:  <Item title:"Street Trees Edit" type:Feature Layer Collection owner:DublinOhio> ID:  <Item title:"Street Trees Edit" type:Feature Layer Collection owner:DublinOhio>
# 	Exporting item
# 	Exporting item complete
# 	Moving item to GIS Layers Backups
# Failed to move item
# 	Item 87 of total 220 complete
# 	ID of backup fa764db80e0c4229a05540db3d49c01e
#
# ******
#
# Processing item:  <Item title:"Subdivisions Edit" type:Feature Layer Collection owner:DublinOhio> ID:  <Item title:"Subdivisions Edit" type:Feature Layer Collection owner:DublinOhio>
# 	Exporting item
# 	Exporting item complete
# 	Moving item to GIS Layers Backups
# Failed to move item
# 	Item 88 of total 220 complete
# 	ID of backup 35033088e764437c844ed88e0c8af1f3
#
# ******
#
# Processing item:  <Item title:"Neighborhoods Edit" type:Feature Layer Collection owner:DublinOhio> ID:  <Item title:"Neighborhoods Edit" type:Feature Layer Collection owner:DublinOhio>
# 	Exporting item
# 	Exporting item complete
# 	Moving item to GIS Layers Backups
# Failed to move item
# 	Item 89 of total 220 complete
# 	ID of backup a5e5a36526e948099e7905f81cba3e0b
#
# ******
#
# Processing item:  <Item title:"Crashes Edit" type:Feature Layer Collection owner:DublinOhio> ID:  <Item title:"Crashes Edit" type:Feature Layer Collection owner:DublinOhio>
# 	Exporting item
# 	Exporting item complete
# 	Moving item to GIS Layers Backups
# Failed to move item
# 	Item 90 of total 220 complete
# 	ID of backup 7a7bfab589fa4d9ca16ab904b890b67b
#
# ******
#
# Processing item:  <Item title:"Bikeways Future Planning Edit" type:Feature Layer Collection owner:DublinOhio> ID:  <Item title:"Bikeways Future Planning Edit" type:Feature Layer Collection owner:DublinOhio>
# 	Exporting item
# 	Exporting item complete
# 	Moving item to GIS Layers Backups
# Failed to move item
# 	Item 91 of total 220 complete
# 	ID of backup 674c4f3274ad45f9a69eac6c1a670987
#
# ******
#
# Processing item:  <Item title:"Bikeways Edit" type:Feature Layer Collection owner:DublinOhio> ID:  <Item title:"Bikeways Edit" type:Feature Layer Collection owner:DublinOhio>
# 	Exporting item
# 	Exporting item complete
# 	Moving item to GIS Layers Backups
# Failed to move item
# 	Item 92 of total 220 complete
# 	ID of backup f5ec26cda347461ca0e2a728dfaffdda
#
# ******
#
# Processing item:  <Item title:"Crosswalks Edit" type:Feature Layer Collection owner:DublinOhio> ID:  <Item title:"Crosswalks Edit" type:Feature Layer Collection owner:DublinOhio>
# 	Exporting item
# 	Exporting item complete
# 	Moving item to GIS Layers Backups
# Failed to move item
# 	Item 93 of total 220 complete
# 	ID of backup b99f96c2bbdf4cdf935ba8e9c946e45c
#
# ******
#
# Processing item:  <Item title:"Event Significant Points Edit" type:Feature Layer Collection owner:DublinOhio> ID:  <Item title:"Event Significant Points Edit" type:Feature Layer Collection owner:DublinOhio>
# 	Exporting item
# 	Exporting item complete
# 	Moving item to GIS Layers Backups
# Failed to move item
# 	Item 94 of total 220 complete
# 	ID of backup 4272d9a4652a48b89fcac539d477e1f8
#
# ******
#
# Processing item:  <Item title:"Memorial Tournament Street Signs Edit (HFL)" type:Feature Layer Collection owner:DublinOhio> ID:  <Item title:"Memorial Tournament Street Signs Edit (HFL)" type:Feature Layer Collection owner:DublinOhio>
# 	Exporting item
# 	Exporting item complete
# 	Moving item to GIS Layers Backups
# Failed to move item
# 	Item 95 of total 220 complete
# 	ID of backup de8f185f0743494d970b58192e28bb67
#
# ******
#
# Processing item:  <Item title:"Street Light Controllers Edit" type:Feature Layer Collection owner:DublinOhio> ID:  <Item title:"Street Light Controllers Edit" type:Feature Layer Collection owner:DublinOhio>
# 	Exporting item
# 	Exporting item complete
# 	Moving item to GIS Layers Backups
# Failed to move item
# 	Item 96 of total 220 complete
# 	ID of backup 843178b7c46e46a8aa3d861a3465a7db
#
# ******
#
# Processing item:  <Item title:"Street Lights Edit" type:Feature Layer Collection owner:DublinOhio> ID:  <Item title:"Street Lights Edit" type:Feature Layer Collection owner:DublinOhio>
# 	Exporting item
# 	Exporting item complete
# 	Moving item to GIS Layers Backups
# Failed to move item
# 	Item 97 of total 220 complete
# 	ID of backup e56fce59c1bc412dbd6099abc3bc8ff4
#
# ******
#
# Processing item:  <Item title:"Sanitary Sewer Edit" type:Feature Layer Collection owner:DublinOhio> ID:  <Item title:"Sanitary Sewer Edit" type:Feature Layer Collection owner:DublinOhio>
# 	Exporting item
# 	Exporting item complete
# 	Moving item to GIS Layers Backups
# Failed to move item
# 	Item 98 of total 220 complete
# 	ID of backup c8c85d9c659b4d9896f852e4b3460f34
#
# ******
#
# Processing item:  <Item title:"TEST Water Features_Edit" type:Feature Layer Collection owner:DublinOhio> ID:  <Item title:"TEST Water Features_Edit" type:Feature Layer Collection owner:DublinOhio>
# 	Exporting item
# 	Exporting item complete
# 	Moving item to GIS Layers Backups
# Failed to move item
# 	Item 99 of total 220 complete
# 	ID of backup 8ba9af84e4b446f1b421a40bd007f266
#
# ******
#
# Processing item:  <Item title:"Damage Assessment Edit" type:Feature Layer Collection owner:DublinOhio> ID:  <Item title:"Damage Assessment Edit" type:Feature Layer Collection owner:DublinOhio>
# 	Exporting item
# 	Exporting item complete
# 	Moving item to GIS Layers Backups
# Failed to move item
# 	Item 100 of total 220 complete
# 	ID of backup b316d0cb021c4aa19d6ab14b59069582
#
# ******
#
# Processing item:  <Item title:"Aerial Grid 2018 Edit" type:Feature Layer Collection owner:DublinOhio> ID:  <Item title:"Aerial Grid 2018 Edit" type:Feature Layer Collection owner:DublinOhio>
# 	Exporting item
# 	Exporting item complete
# 	Moving item to GIS Layers Backups
# Failed to move item
# 	Item 101 of total 220 complete
# 	ID of backup c38e9bbab67c486c94663a96ccce7c20
#
# ******
#
# Processing item:  <Item title:"Sanitary Flow Meters Edit" type:Feature Layer Collection owner:DublinOhio> ID:  <Item title:"Sanitary Flow Meters Edit" type:Feature Layer Collection owner:DublinOhio>
# 	Exporting item
# 	Exporting item complete
# 	Moving item to GIS Layers Backups
# Failed to move item
# 	Item 102 of total 220 complete
# 	ID of backup ccb5eb8539154e5f888b711543f1539e
#
# ******
#
# Processing item:  <Item title:"Guardrails Edit" type:Feature Layer Collection owner:DublinOhio> ID:  <Item title:"Guardrails Edit" type:Feature Layer Collection owner:DublinOhio>
# 	Exporting item
# 	Exporting item complete
# 	Moving item to GIS Layers Backups
# Failed to move item
# 	Item 103 of total 220 complete
# 	ID of backup 21779840ecfd46ca87613a363f6406b9
#
# ******
#
# Processing item:  <Item title:"Signature Event Restroom Locations Edit" type:Feature Layer Collection owner:DublinOhio> ID:  <Item title:"Signature Event Restroom Locations Edit" type:Feature Layer Collection owner:DublinOhio>
# 	Exporting item
# 	Exporting item complete
# 	Moving item to GIS Layers Backups
# Failed to move item
# 	Item 104 of total 220 complete
# 	ID of backup e16bf5cbddc84189baa7acc0772445a1
#
# ******
#
# Processing item:  <Item title:"Bridge Street District Street Network Edit" type:Feature Layer Collection owner:DublinOhio> ID:  <Item title:"Bridge Street District Street Network Edit" type:Feature Layer Collection owner:DublinOhio>
# 	Exporting item
# 	Exporting item complete
# 	Moving item to GIS Layers Backups
# Failed to move item
# 	Item 105 of total 220 complete
# 	ID of backup 378826ce423b4de88c1ff81b29698f92
#
# ******
#
# Processing item:  <Item title:"Curbs Edit" type:Feature Layer Collection owner:DublinOhio> ID:  <Item title:"Curbs Edit" type:Feature Layer Collection owner:DublinOhio>
# 	Exporting item
# Failed Exporting Item
# 	Moving item to GIS Layers Backups
# Failed to move item
# 	Item 106 of total 220 complete
# 	ID of backup 378826ce423b4de88c1ff81b29698f92
#
# ******
#
# Processing item:  <Item title:"Smart Mobility Areas Edit" type:Feature Layer Collection owner:DublinOhio> ID:  <Item title:"Smart Mobility Areas Edit" type:Feature Layer Collection owner:DublinOhio>
# 	Exporting item
# 	Exporting item complete
# 	Moving item to GIS Layers Backups
# Failed to move item
# 	Item 107 of total 220 complete
# 	ID of backup 7642d9cac2e94cf385f8c736bcf64caa
#
# ******
#
# Processing item:  <Item title:"Sidewalks Edit" type:Feature Layer Collection owner:DublinOhio> ID:  <Item title:"Sidewalks Edit" type:Feature Layer Collection owner:DublinOhio>
# 	Exporting item
# 	Exporting item complete
# 	Moving item to GIS Layers Backups
# Failed to move item
# 	Item 108 of total 220 complete
# 	ID of backup a2d9120a955e48cb8d8094b1bd6bafdb
#
# ******
#
# Processing item:  <Item title:"Stream Outfalls Edit" type:Feature Layer Collection owner:DublinOhio> ID:  <Item title:"Stream Outfalls Edit" type:Feature Layer Collection owner:DublinOhio>
# 	Exporting item
# 	Exporting item complete
# 	Moving item to GIS Layers Backups
# Failed to move item
# 	Item 109 of total 220 complete
# 	ID of backup cdb9d069a1854cc788244e75f7be3bc6
#
# ******
#
# Processing item:  <Item title:"Aerial Photo Extent Edit" type:Feature Layer Collection owner:DublinOhio> ID:  <Item title:"Aerial Photo Extent Edit" type:Feature Layer Collection owner:DublinOhio>
# 	Exporting item
# 	Exporting item complete
# 	Moving item to GIS Layers Backups
# Failed to move item
# 	Item 110 of total 220 complete
# 	ID of backup b0e677fee9d04c75bda2a516e1f478ff
#
# ******
#
# Processing item:  <Item title:"Existing Land Use 2012 Edit (Current Production)" type:Feature Layer Collection owner:DublinOhio> ID:  <Item title:"Existing Land Use 2012 Edit (Current Production)" type:Feature Layer Collection owner:DublinOhio>
# 	Exporting item
# 	Exporting item complete
# 	Moving item to GIS Layers Backups
# Failed to move item
# 	Item 111 of total 220 complete
# 	ID of backup 600a4d4c60d24d35a3ee252c181bf546
#
# ******
#
# Processing item:  <Item title:"Census Blocks 2010 Edit" type:Feature Layer Collection owner:DublinOhio> ID:  <Item title:"Census Blocks 2010 Edit" type:Feature Layer Collection owner:DublinOhio>
# 	Exporting item
# 	Exporting item complete
# 	Moving item to GIS Layers Backups
# Failed to move item
# 	Item 112 of total 220 complete
# 	ID of backup daa31883c8414911b55dbcd75d4a16d4
#
# ******
#
# Processing item:  <Item title:"Traffic Signal Fiber Edit" type:Feature Layer Collection owner:DublinOhio> ID:  <Item title:"Traffic Signal Fiber Edit" type:Feature Layer Collection owner:DublinOhio>
# 	Exporting item
# 	Exporting item complete
# 	Moving item to GIS Layers Backups
# Failed to move item
# 	Item 113 of total 220 complete
# 	ID of backup 6ff8e2dda6f14dfabae2f6de0f140513
#
# ******
#
# Processing item:  <Item title:"Pavement Striping Edit" type:Feature Layer Collection owner:DublinOhio> ID:  <Item title:"Pavement Striping Edit" type:Feature Layer Collection owner:DublinOhio>
# 	Exporting item
# 	Exporting item complete
# 	Moving item to GIS Layers Backups
# Failed to move item
# 	Item 114 of total 220 complete
# 	ID of backup 27d69e6a71d04828bdf84887d8f807ed
#
# ******
#
# Processing item:  <Item title:"Utility Revenue Sharing Areas Edit" type:Feature Layer Collection owner:DublinOhio> ID:  <Item title:"Utility Revenue Sharing Areas Edit" type:Feature Layer Collection owner:DublinOhio>
# 	Exporting item
# 	Exporting item complete
# 	Moving item to GIS Layers Backups
# Failed to move item
# 	Item 115 of total 220 complete
# 	ID of backup ae8fad91b0854c02bf29190169237e23
#
# ******
#
# Processing item:  <Item title:"Cemeteries Edit" type:Feature Layer Collection owner:DublinOhio> ID:  <Item title:"Cemeteries Edit" type:Feature Layer Collection owner:DublinOhio>
# 	Exporting item
# 	Exporting item complete
# 	Moving item to GIS Layers Backups
# Failed to move item
# 	Item 116 of total 220 complete
# 	ID of backup 49fb60ea2d4d41e68142a9b81abb56ce
#
# ******
#
# Processing item:  <Item title:"St Signs Small Golf Tournament Edit" type:Feature Layer Collection owner:rfrantz@dublin.oh.us_DublinOhio> ID:  <Item title:"St Signs Small Golf Tournament Edit" type:Feature Layer Collection owner:rfrantz@dublin.oh.us_DublinOhio>
# 	Exporting item
# 	Exporting item complete
# 	Moving item to GIS Layers Backups
# Failed to move item
# 	Item 117 of total 220 complete
# 	ID of backup ca092af9147541239f2015bd9e6b3026
#
# ******
#
# Processing item:  <Item title:"Aerial Grid 2005 to 2007 Edit" type:Feature Layer Collection owner:DublinOhio> ID:  <Item title:"Aerial Grid 2005 to 2007 Edit" type:Feature Layer Collection owner:DublinOhio>
# 	Exporting item
# 	Exporting item complete
# 	Moving item to GIS Layers Backups
# Failed to move item
# 	Item 118 of total 220 complete
# 	ID of backup 5095d3e947af457e8c70f802541aca44
#
# ******
#
# Processing item:  <Item title:"Citizen U Edit" type:Feature Layer Collection owner:DublinOhio> ID:  <Item title:"Citizen U Edit" type:Feature Layer Collection owner:DublinOhio>
# 	Exporting item
# 	Exporting item complete
# 	Moving item to GIS Layers Backups
# Failed to move item
# 	Item 119 of total 220 complete
# 	ID of backup 707052b5cf3640d4ac0786fbeb13a915
#
# ******
#
# Processing item:  <Item title:"Electric Circuit Areas Edit" type:Feature Layer Collection owner:DublinOhio> ID:  <Item title:"Electric Circuit Areas Edit" type:Feature Layer Collection owner:DublinOhio>
# 	Exporting item
# 	Exporting item complete
# 	Moving item to GIS Layers Backups
# Failed to move item
# 	Item 120 of total 220 complete
# 	ID of backup 6a135a6a5a4e42e3bfd65a23a81c8d58
#
# ******
#
# Processing item:  <Item title:"Memorial Grid Edit" type:Feature Layer Collection owner:DublinOhio> ID:  <Item title:"Memorial Grid Edit" type:Feature Layer Collection owner:DublinOhio>
# 	Exporting item
# 	Exporting item complete
# 	Moving item to GIS Layers Backups
# Failed to move item
# 	Item 121 of total 220 complete
# 	ID of backup d5a4574fce8b49a0ba76c43d876db4d3
#
# ******
#
# Processing item:  <Item title:"Soils Edit" type:Feature Layer Collection owner:DublinOhio> ID:  <Item title:"Soils Edit" type:Feature Layer Collection owner:DublinOhio>
# 	Exporting item
# 	Exporting item complete
# 	Moving item to GIS Layers Backups
# Failed to move item
# 	Item 122 of total 220 complete
# 	ID of backup 6a9984b9c43840fba18042828ea0a88a
#
# ******
#
# Processing item:  <Item title:"Recreation Points of Interest Edit" type:Feature Layer Collection owner:DublinOhio> ID:  <Item title:"Recreation Points of Interest Edit" type:Feature Layer Collection owner:DublinOhio>
# 	Exporting item
# 	Exporting item complete
# 	Moving item to GIS Layers Backups
# Failed to move item
# 	Item 123 of total 220 complete
# 	ID of backup d6d8848175f244f784e8d6b681697bb3
#
# ******
#
# Processing item:  <Item title:"Parcels Edit" type:Feature Layer Collection owner:DublinOhio> ID:  <Item title:"Parcels Edit" type:Feature Layer Collection owner:DublinOhio>
# 	Exporting item
# 	Exporting item complete
# 	Moving item to GIS Layers Backups
# Failed to move item
# 	Item 124 of total 220 complete
# 	ID of backup 73115f7cb5a8437096ee93661d14f065
#
# ******
#
# Processing item:  <Item title:"County Permissive Tax Roads Edit" type:Feature Layer Collection owner:DublinOhio> ID:  <Item title:"County Permissive Tax Roads Edit" type:Feature Layer Collection owner:DublinOhio>
# 	Exporting item
# 	Exporting item complete
# 	Moving item to GIS Layers Backups
# Failed to move item
# 	Item 125 of total 220 complete
# 	ID of backup fe06c030b5f649fc9c3738c2523c34a5
#
# ******
#
# Processing item:  <Item title:"Art In Public Places Edit" type:Feature Layer Collection owner:DublinOhio> ID:  <Item title:"Art In Public Places Edit" type:Feature Layer Collection owner:DublinOhio>
# 	Exporting item
# 	Exporting item complete
# 	Moving item to GIS Layers Backups
# Failed to move item
# 	Item 126 of total 220 complete
# 	ID of backup ef6d7717a46b4e78834c68b3306ca542
#
# ******
#
# Processing item:  <Item title:"Code Enforcement Landscape Notes Edit" type:Feature Layer Collection owner:DublinOhio> ID:  <Item title:"Code Enforcement Landscape Notes Edit" type:Feature Layer Collection owner:DublinOhio>
# 	Exporting item
# 	Exporting item complete
# 	Moving item to GIS Layers Backups
# Failed to move item
# 	Item 127 of total 220 complete
# 	ID of backup 34c444531c60409582a14a4f52627479
#
# ******
#
# Processing item:  <Item title:"Dublink Edit" type:Feature Layer Collection owner:DublinOhio> ID:  <Item title:"Dublink Edit" type:Feature Layer Collection owner:DublinOhio>
# 	Exporting item
# 	Exporting item complete
# 	Moving item to GIS Layers Backups
# Failed to move item
# 	Item 128 of total 220 complete
# 	ID of backup 12d810bf2d9e48e0a212555c5897a1db
#
# ******
#
# Processing item:  <Item title:"2003 Aerial Grid Edit" type:Feature Layer Collection owner:DublinOhio> ID:  <Item title:"2003 Aerial Grid Edit" type:Feature Layer Collection owner:DublinOhio>
# 	Exporting item
# 	Exporting item complete
# 	Moving item to GIS Layers Backups
# Failed to move item
# 	Item 129 of total 220 complete
# 	ID of backup 1bdebcf5461f44b1b95a9089e542c5f2
#
# ******
#
# Processing item:  <Item title:"Signature Event Tents Edit" type:Feature Layer Collection owner:DublinOhio> ID:  <Item title:"Signature Event Tents Edit" type:Feature Layer Collection owner:DublinOhio>
# 	Exporting item
# 	Exporting item complete
# 	Moving item to GIS Layers Backups
# Failed to move item
# 	Item 130 of total 220 complete
# 	ID of backup d98a8c70138d4b9db88f875ab0690401
#
# ******
#
# Processing item:  <Item title:"Counties Edit" type:Feature Layer Collection owner:DublinOhio> ID:  <Item title:"Counties Edit" type:Feature Layer Collection owner:DublinOhio>
# 	Exporting item
# 	Exporting item complete
# 	Moving item to GIS Layers Backups
# Failed to move item
# 	Item 131 of total 220 complete
# 	ID of backup 96b1bfaa690d44588a53e5b422337f1e
#
# ******
#
# Processing item:  <Item title:"Pavement Markings Edit" type:Feature Layer Collection owner:DublinOhio> ID:  <Item title:"Pavement Markings Edit" type:Feature Layer Collection owner:DublinOhio>
# 	Exporting item
# 	Exporting item complete
# 	Moving item to GIS Layers Backups
# Failed to move item
# 	Item 132 of total 220 complete
# 	ID of backup 45292c7236d148be995b21686f0f5a4d
#
# ******
#
# Processing item:  <Item title:"Tree Canopy 2010" type:Feature Layer Collection owner:DublinOhio> ID:  <Item title:"Tree Canopy 2010" type:Feature Layer Collection owner:DublinOhio>
# 	Exporting item
# 	Exporting item complete
# 	Moving item to GIS Layers Backups
# Failed to move item
# 	Item 133 of total 220 complete
# 	ID of backup b7681e9d86254bef861b53687087680e
#
# ******
#
# Processing item:  <Item title:"Elementary Attendance Areas" type:Feature Layer Collection owner:DublinOhio> ID:  <Item title:"Elementary Attendance Areas" type:Feature Layer Collection owner:DublinOhio>
# 	Exporting item
# 	Exporting item complete
# 	Moving item to GIS Layers Backups
# Failed to move item
# 	Item 134 of total 220 complete
# 	ID of backup b5e84d8af57b400da74d32f032f5aef6
#
# ******
#
# Processing item:  <Item title:"Memorial Tournament Street Signs Install (HFL Edit Att)" type:Feature Layer Collection owner:DublinOhio> ID:  <Item title:"Memorial Tournament Street Signs Install (HFL Edit Att)" type:Feature Layer Collection owner:DublinOhio>
# 	Exporting item

# %%
def removeBkupTagList(backupTag = "HFLBackupIncludeYes"):
    print("Searching for content with tag: ", backupTag)
    bkupContentList = gis.content.search(query="tags:"+ backupTag, 
                                item_type="File Geodatabase",  
                                max_items=2000)
    print("Query Results to Backup:\n", bkupContentList)
    
    backupitemIDs = []
    
    for i in bkupContentList:
        backupitemIDs.append(i.id)
        
    # get item ids
    return backupitemIDs

# %%
removelist = removeBkupTagList(backupTag = "HFLBackupIncludeYes")

# %%
removeBackupTagsFromBackups(removelist)
